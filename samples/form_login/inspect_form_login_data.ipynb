# %% [markdown]
# # Mask R-CNN - Inspect Form_login Training Data
#
# Inspect and visualize data loading and pre-processing code.

# %%
import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.form_login import form_login

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations
#
# Configurations are defined in form_login.py

# %%
config = form_login.Form_loginConfig()
BALLOON_DIR = os.path.join(ROOT_DIR, "datasets/form_login_ilya/train_filtered")

# %% [markdown]
# ## Dataset

# %%
# Load dataset
# Get the dataset from the releases page
# https://github.com/matterport/Mask_RCNN/releases
dataset = form_login.Form_loginDataset()
dataset.load_form_login(BALLOON_DIR, "train")

# Must call before using the dataset
dataset.prepare()

print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# {'name': 'rect', 'x': 28, 'y': 49, 'width': 115, 'height': 41}
# {'name': 'rect', 'x': 32, 'y': 118, 'width': 221, 'height': 38}
# {'name': 'rect', 'x': 33, 'y': 162, 'width': 221, 'height': 35}
# {'name': 'rect', 'x': 31, 'y': 202, 'width': 222, 'height': 39}
# {'name': 'rect', 'x': 31, 'y': 253, 'width': 18, 'height': 25}
# {'name': 'rect', 'x': 54, 'y': 258, 'width': 199, 'height': 20}
# {'name': 'rect', 'x': 130, 'y': 293, 'width': 125, 'height': 62}
# {'name': 'rect', 'x': 15, 'y': 24, 'width': 461, 'height': 61}
# {'name': 'rect', 'x': 14, 'y': 94, 'width': 461, 'height': 56}
# {'name': 'rect', 'x': 12, 'y': 158, 'width': 461, 'height': 58}
# {'name': 'rect', 'x': 156, 'y': 225, 'width': 174, 'height': 51}
# {'name': 'rect', 'x': 180, 'y': 300, 'width': 128, 'height': 25}
# {'name': 'rect', 'x': 14, 'y': 278, 'width': 460, 'height': 22}
# {'name': 'rect', 'x': 16, 'y': 327, 'width': 115, 'height': 47}
# {'name': 'rect', 'x': 249, 'y': 329, 'width': 114, 'height': 47}
# {'name': 'rect', 'x': 137, 'y': 326, 'width': 114, 'height': 48}
# {'name': 'rect', 'x': 368, 'y': 326, 'width': 114, 'height': 52}
# {'name': 'rect', 'x': 137, 'y': 326, 'width': 114, 'height': 52}
# {'name': 'rect', 'x': 33, 'y': 391, 'width': 418, 'height': 22}
# {'name': 'rect', 'x': 206, 'y': 28, 'width': 136, 'height': 35}
# {'name': 'rect', 'x': 184, 'y': 163, 'width': 188, 'height': 176}
# {'name': 'rect', 'x': 184, 'y': 358, 'width': 180, 'height': 39}
# {'name': 'rect', 'x': 97, 'y': 403, 'width': 371, 'height': 41}
# {'name': 'rect', 'x': 68, 'y': 473, 'width': 418, 'height': 95}
# {'name': 'rect', 'x': 70, 'y': 571, 'width': 416, 'height': 80}
# {'name': 'rect', 'x': 73, 'y': 649, 'width': 415, 'height': 89}
# {'name': 'rect', 'x': 68, 'y': 736, 'width': 418, 'height': 88}
# {'name': 'rect', 'x': 37, 'y': 29, 'width': 369, 'height': 51}
# {'name': 'rect', 'x': 56, 'y': 90, 'width': 338, 'height': 38}
# {'name': 'rect', 'x': 20, 'y': 136, 'width': 201, 'height': 50}
# {'name': 'rect', 'x': 226, 'y': 136, 'width': 199, 'height': 49}
# {'name': 'rect', 'x': 23, 'y': 193, 'width': 403, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 240, 'width': 201, 'height': 48}
# {'name': 'rect', 'x': 230, 'y': 243, 'width': 197, 'height': 42}
# {'name': 'rect', 'x': 132, 'y': 305, 'width': 179, 'height': 47}
# {'name': 'rect', 'x': 14, 'y': 362, 'width': 413, 'height': 16}
# {'name': 'rect', 'x': 124, 'y': 388, 'width': 197, 'height': 23}
# {'name': 'rect', 'x': 21, 'y': 417, 'width': 201, 'height': 50}
# {'name': 'rect', 'x': 227, 'y': 418, 'width': 205, 'height': 47}
# {'name': 'rect', 'x': 124, 'y': 7, 'width': 106, 'height': 58}
# {'name': 'rect', 'x': 311, 'y': 6, 'width': 46, 'height': 105}
# {'name': 'rect', 'x': 142, 'y': 91, 'width': 84, 'height': 26}
# {'name': 'rect', 'x': 108, 'y': 126, 'width': 157, 'height': 28}
# {'name': 'rect', 'x': 17, 'y': 187, 'width': 335, 'height': 72}
# {'name': 'rect', 'x': 20, 'y': 265, 'width': 332, 'height': 55}
# {'name': 'rect', 'x': 22, 'y': 325, 'width': 330, 'height': 60}
# {'name': 'rect', 'x': 22, 'y': 391, 'width': 329, 'height': 60}
# {'name': 'rect', 'x': 18, 'y': 468, 'width': 333, 'height': 58}
# {'name': 'rect', 'x': 23, 'y': 15, 'width': 435, 'height': 53}
# {'name': 'rect', 'x': 19, 'y': 89, 'width': 485, 'height': 55}
# {'name': 'rect', 'x': 246, 'y': 153, 'width': 34, 'height': 21}
# {'name': 'rect', 'x': 22, 'y': 186, 'width': 240, 'height': 58}
# {'name': 'rect', 'x': 264, 'y': 181, 'width': 241, 'height': 58}
# {'name': 'rect', 'x': 22, 'y': 244, 'width': 485, 'height': 57}
# {'name': 'rect', 'x': 22, 'y': 305, 'width': 483, 'height': 54}
# {'name': 'rect', 'x': 21, 'y': 361, 'width': 488, 'height': 68}
# {'name': 'rect', 'x': 19, 'y': 434, 'width': 490, 'height': 42}
# {'name': 'rect', 'x': 18, 'y': 490, 'width': 184, 'height': 24}
# {'name': 'rect', 'x': 17, 'y': 4, 'width': 416, 'height': 44}
# {'name': 'rect', 'x': 19, 'y': 58, 'width': 271, 'height': 28}
# {'name': 'rect', 'x': 19, 'y': 101, 'width': 202, 'height': 47}
# {'name': 'rect', 'x': 227, 'y': 101, 'width': 200, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 155, 'width': 406, 'height': 44}
# {'name': 'rect', 'x': 19, 'y': 202, 'width': 408, 'height': 42}
# {'name': 'rect', 'x': 20, 'y': 259, 'width': 74, 'height': 23}
# {'name': 'rect', 'x': 23, 'y': 289, 'width': 55, 'height': 29}
# {'name': 'rect', 'x': 81, 'y': 287, 'width': 65, 'height': 33}
# {'name': 'rect', 'x': 148, 'y': 286, 'width': 63, 'height': 35}
# {'name': 'rect', 'x': 304, 'y': 357, 'width': 29, 'height': 24}
# {'name': 'rect', 'x': 19, 'y': 324, 'width': 67, 'height': 25}
# {'name': 'rect', 'x': 26, 'y': 353, 'width': 21, 'height': 30}
# {'name': 'rect', 'x': 131, 'y': 356, 'width': 19, 'height': 29}
# {'name': 'rect', 'x': 205, 'y': 353, 'width': 23, 'height': 29}
# {'name': 'rect', 'x': 50, 'y': 356, 'width': 62, 'height': 29}
# {'name': 'rect', 'x': 151, 'y': 359, 'width': 46, 'height': 21}
# {'name': 'rect', 'x': 232, 'y': 357, 'width': 65, 'height': 24}
# {'name': 'rect', 'x': 217, 'y': 291, 'width': 29, 'height': 24}
# {'name': 'rect', 'x': 17, 'y': 393, 'width': 321, 'height': 58}
# {'name': 'rect', 'x': 16, 'y': 455, 'width': 221, 'height': 49}
# {'name': 'rect', 'x': 86, 'y': 3, 'width': 434, 'height': 45}
# {'name': 'rect', 'x': 96, 'y': 56, 'width': 407, 'height': 17}
# {'name': 'rect', 'x': 23, 'y': 99, 'width': 564, 'height': 70}
# {'name': 'rect', 'x': 24, 'y': 178, 'width': 561, 'height': 28}
# {'name': 'rect', 'x': 23, 'y': 224, 'width': 563, 'height': 70}
# {'name': 'rect', 'x': 25, 'y': 300, 'width': 561, 'height': 74}
# {'name': 'rect', 'x': 7, 'y': 6, 'width': 452, 'height': 46}
# {'name': 'rect', 'x': 6, 'y': 58, 'width': 266, 'height': 25}
# {'name': 'rect', 'x': 4, 'y': 102, 'width': 88, 'height': 32}
# {'name': 'rect', 'x': 8, 'y': 138, 'width': 449, 'height': 57}
# {'name': 'rect', 'x': 10, 'y': 213, 'width': 62, 'height': 27}
# {'name': 'rect', 'x': 8, 'y': 244, 'width': 449, 'height': 66}
# {'name': 'rect', 'x': 9, 'y': 324, 'width': 101, 'height': 29}
# {'name': 'rect', 'x': 8, 'y': 361, 'width': 445, 'height': 57}
# {'name': 'rect', 'x': 8, 'y': 430, 'width': 450, 'height': 63}
# {'name': 'rect', 'x': 9, 'y': 504, 'width': 447, 'height': 57}
# {'name': 'rect', 'x': 6, 'y': 598, 'width': 424, 'height': 58}
# {'name': 'rect', 'x': 9, 'y': 7, 'width': 205, 'height': 61}
# {'name': 'rect', 'x': 506, 'y': 10, 'width': 158, 'height': 57}
# {'name': 'rect', 'x': 20, 'y': 96, 'width': 431, 'height': 37}
# {'name': 'rect', 'x': 13, 'y': 151, 'width': 102, 'height': 29}
# {'name': 'rect', 'x': 230, 'y': 139, 'width': 284, 'height': 53}
# {'name': 'rect', 'x': 20, 'y': 210, 'width': 616, 'height': 101}
# {'name': 'rect', 'x': 24, 'y': 333, 'width': 84, 'height': 33}
# {'name': 'rect', 'x': 22, 'y': 402, 'width': 152, 'height': 42}
# {'name': 'rect', 'x': 19, 'y': 468, 'width': 105, 'height': 38}
# {'name': 'rect', 'x': 17, 'y': 543, 'width': 98, 'height': 35}
# {'name': 'rect', 'x': 14, 'y': 607, 'width': 137, 'height': 38}
# {'name': 'rect', 'x': 227, 'y': 326, 'width': 287, 'height': 50}
# {'name': 'rect', 'x': 227, 'y': 395, 'width': 283, 'height': 51}
# {'name': 'rect', 'x': 229, 'y': 461, 'width': 284, 'height': 55}
# {'name': 'rect', 'x': 228, 'y': 531, 'width': 284, 'height': 54}
# {'name': 'rect', 'x': 228, 'y': 604, 'width': 286, 'height': 51}
# {'name': 'rect', 'x': 24, 'y': 683, 'width': 22, 'height': 26}
# {'name': 'rect', 'x': 50, 'y': 686, 'width': 560, 'height': 28}
# {'name': 'rect', 'x': 22, 'y': 720, 'width': 461, 'height': 30}
# {'name': 'rect', 'x': 184, 'y': 774, 'width': 302, 'height': 61}
# {'name': 'rect', 'x': 16, 'y': 140, 'width': 322, 'height': 57}
# {'name': 'rect', 'x': 78, 'y': 212, 'width': 191, 'height': 72}
# {'name': 'rect', 'x': 92, 'y': 18, 'width': 175, 'height': 42}
# {'name': 'rect', 'x': 12, 'y': 76, 'width': 324, 'height': 59}
# {'name': 'rect', 'x': 34, 'y': 8, 'width': 248, 'height': 27}
# {'name': 'rect', 'x': 16, 'y': 51, 'width': 138, 'height': 58}
# {'name': 'rect', 'x': 161, 'y': 52, 'width': 136, 'height': 57}
# {'name': 'rect', 'x': 28, 'y': 122, 'width': 268, 'height': 42}
# {'name': 'rect', 'x': 21, 'y': 174, 'width': 273, 'height': 49}
# {'name': 'rect', 'x': 22, 'y': 228, 'width': 273, 'height': 44}
# {'name': 'rect', 'x': 191, 'y': 268, 'width': 105, 'height': 21}
# {'name': 'rect', 'x': 19, 'y': 292, 'width': 285, 'height': 60}
# {'name': 'rect', 'x': 5, 'y': 14, 'width': 324, 'height': 100}
# {'name': 'rect', 'x': 10, 'y': 145, 'width': 83, 'height': 28}
# {'name': 'rect', 'x': 9, 'y': 179, 'width': 410, 'height': 58}
# {'name': 'rect', 'x': 6, 'y': 246, 'width': 117, 'height': 27}
# {'name': 'rect', 'x': 7, 'y': 279, 'width': 414, 'height': 59}
# {'name': 'rect', 'x': 11, 'y': 349, 'width': 79, 'height': 21}
# {'name': 'rect', 'x': 9, 'y': 378, 'width': 412, 'height': 63}
# {'name': 'rect', 'x': 8, 'y': 451, 'width': 199, 'height': 25}
# {'name': 'rect', 'x': 6, 'y': 482, 'width': 412, 'height': 58}
# {'name': 'rect', 'x': 7, 'y': 545, 'width': 412, 'height': 68}
# {'name': 'rect', 'x': 4, 'y': 625, 'width': 415, 'height': 32}
# {'name': 'rect', 'x': 5, 'y': 675, 'width': 418, 'height': 66}
# {'name': 'rect', 'x': 209, 'y': 73, 'width': 68, 'height': 56}
# {'name': 'rect', 'x': 110, 'y': 133, 'width': 268, 'height': 33}
# {'name': 'rect', 'x': 243, 'y': 181, 'width': 81, 'height': 26}
# {'name': 'rect', 'x': 16, 'y': 182, 'width': 67, 'height': 25}
# {'name': 'rect', 'x': 14, 'y': 210, 'width': 222, 'height': 52}
# {'name': 'rect', 'x': 242, 'y': 203, 'width': 224, 'height': 61}
# {'name': 'rect', 'x': 17, 'y': 267, 'width': 64, 'height': 20}
# {'name': 'rect', 'x': 13, 'y': 290, 'width': 461, 'height': 55}
# {'name': 'rect', 'x': 14, 'y': 353, 'width': 60, 'height': 15}
# {'name': 'rect', 'x': 13, 'y': 372, 'width': 462, 'height': 53}
# {'name': 'rect', 'x': 13, 'y': 431, 'width': 95, 'height': 18}
# {'name': 'rect', 'x': 12, 'y': 456, 'width': 145, 'height': 47}
# {'name': 'rect', 'x': 167, 'y': 449, 'width': 297, 'height': 60}
# {'name': 'rect', 'x': 10, 'y': 511, 'width': 64, 'height': 18}
# {'name': 'rect', 'x': 14, 'y': 537, 'width': 224, 'height': 49}
# {'name': 'rect', 'x': 245, 'y': 533, 'width': 111, 'height': 53}
# {'name': 'rect', 'x': 363, 'y': 530, 'width': 109, 'height': 58}
# {'name': 'rect', 'x': 12, 'y': 600, 'width': 465, 'height': 103}
# {'name': 'rect', 'x': 143, 'y': 711, 'width': 204, 'height': 57}
# {'name': 'rect', 'x': 314, 'y': 5, 'width': 92, 'height': 42}
# {'name': 'rect', 'x': 77, 'y': 8, 'width': 232, 'height': 37}
# {'name': 'rect', 'x': 62, 'y': 12, 'width': 209, 'height': 71}
# {'name': 'rect', 'x': 24, 'y': 83, 'width': 284, 'height': 50}
# {'name': 'rect', 'x': 24, 'y': 140, 'width': 283, 'height': 45}
# {'name': 'rect', 'x': 25, 'y': 192, 'width': 287, 'height': 27}
# {'name': 'rect', 'x': 27, 'y': 224, 'width': 282, 'height': 42}
# {'name': 'rect', 'x': 29, 'y': 267, 'width': 278, 'height': 46}
# {'name': 'rect', 'x': 29, 'y': 313, 'width': 275, 'height': 41}
# {'name': 'rect', 'x': 26, 'y': 352, 'width': 279, 'height': 46}
# {'name': 'rect', 'x': 27, 'y': 406, 'width': 277, 'height': 43}
# {'name': 'rect', 'x': 53, 'y': 456, 'width': 226, 'height': 64}
# {'name': 'rect', 'x': 16, 'y': 15, 'width': 94, 'height': 42}
# {'name': 'rect', 'x': 15, 'y': 64, 'width': 338, 'height': 34}
# {'name': 'rect', 'x': 14, 'y': 100, 'width': 167, 'height': 39}
# {'name': 'rect', 'x': 16, 'y': 151, 'width': 186, 'height': 54}
# {'name': 'rect', 'x': 208, 'y': 151, 'width': 187, 'height': 56}
# {'name': 'rect', 'x': 17, 'y': 211, 'width': 382, 'height': 50}
# {'name': 'rect', 'x': 17, 'y': 263, 'width': 222, 'height': 19}
# {'name': 'rect', 'x': 12, 'y': 308, 'width': 164, 'height': 45}
# {'name': 'rect', 'x': 182, 'y': 305, 'width': 166, 'height': 50}
# {'name': 'rect', 'x': 348, 'y': 300, 'width': 54, 'height': 58}
# {'name': 'rect', 'x': 9, 'y': 359, 'width': 340, 'height': 44}
# {'name': 'rect', 'x': 14, 'y': 439, 'width': 125, 'height': 24}
# {'name': 'rect', 'x': 288, 'y': 422, 'width': 115, 'height': 60}
# {'name': 'rect', 'x': 67, 'y': 31, 'width': 89, 'height': 45}
# {'name': 'rect', 'x': 170, 'y': 30, 'width': 95, 'height': 49}
# {'name': 'rect', 'x': 415, 'y': 36, 'width': 94, 'height': 49}
# {'name': 'rect', 'x': 69, 'y': 95, 'width': 432, 'height': 85}
# {'name': 'rect', 'x': 72, 'y': 180, 'width': 432, 'height': 73}
# {'name': 'rect', 'x': 70, 'y': 256, 'width': 438, 'height': 79}
# {'name': 'rect', 'x': 12, 'y': 7, 'width': 649, 'height': 73}
# {'name': 'rect', 'x': 237, 'y': 89, 'width': 199, 'height': 40}
# {'name': 'rect', 'x': 234, 'y': 135, 'width': 202, 'height': 45}
# {'name': 'rect', 'x': 256, 'y': 202, 'width': 162, 'height': 36}
# {'name': 'rect', 'x': 10, 'y': 237, 'width': 56, 'height': 24}
# {'name': 'rect', 'x': 11, 'y': 366, 'width': 78, 'height': 25}
# {'name': 'rect', 'x': 18, 'y': 260, 'width': 640, 'height': 50}
# {'name': 'rect', 'x': 17, 'y': 387, 'width': 639, 'height': 53}
# {'name': 'rect', 'x': 501, 'y': 448, 'width': 155, 'height': 18}
# {'name': 'rect', 'x': 545, 'y': 475, 'width': 114, 'height': 49}
# {'name': 'rect', 'x': 103, 'y': 24, 'width': 356, 'height': 37}
# {'name': 'rect', 'x': 154, 'y': 66, 'width': 255, 'height': 23}
# {'name': 'rect', 'x': 26, 'y': 102, 'width': 507, 'height': 33}
# {'name': 'rect', 'x': 29, 'y': 140, 'width': 503, 'height': 50}
# {'name': 'rect', 'x': 43, 'y': 184, 'width': 247, 'height': 20}
# {'name': 'rect', 'x': 31, 'y': 210, 'width': 499, 'height': 54}
# {'name': 'rect', 'x': 28, 'y': 274, 'width': 503, 'height': 57}
# {'name': 'rect', 'x': 28, 'y': 339, 'width': 247, 'height': 60}
# {'name': 'rect', 'x': 283, 'y': 340, 'width': 247, 'height': 59}
# {'name': 'rect', 'x': 26, 'y': 406, 'width': 508, 'height': 71}
# {'name': 'rect', 'x': 26, 'y': 487, 'width': 507, 'height': 23}
# {'name': 'rect', 'x': 153, 'y': 517, 'width': 60, 'height': 58}
# {'name': 'rect', 'x': 220, 'y': 518, 'width': 57, 'height': 58}
# {'name': 'rect', 'x': 283, 'y': 515, 'width': 57, 'height': 62}
# {'name': 'rect', 'x': 346, 'y': 516, 'width': 64, 'height': 61}
# {'name': 'rect', 'x': 34, 'y': 5, 'width': 370, 'height': 117}
# {'name': 'rect', 'x': 52, 'y': 136, 'width': 333, 'height': 56}
# {'name': 'rect', 'x': 20, 'y': 213, 'width': 116, 'height': 30}
# {'name': 'rect', 'x': 173, 'y': 214, 'width': 91, 'height': 26}
# {'name': 'rect', 'x': 319, 'y': 207, 'width': 86, 'height': 33}
# {'name': 'rect', 'x': 40, 'y': 248, 'width': 355, 'height': 53}
# {'name': 'rect', 'x': 31, 'y': 314, 'width': 72, 'height': 25}
# {'name': 'rect', 'x': 26, 'y': 403, 'width': 78, 'height': 26}
# {'name': 'rect', 'x': 25, 'y': 492, 'width': 104, 'height': 25}
# {'name': 'rect', 'x': 23, 'y': 578, 'width': 107, 'height': 28}
# {'name': 'rect', 'x': 24, 'y': 338, 'width': 393, 'height': 60}
# {'name': 'rect', 'x': 25, 'y': 424, 'width': 387, 'height': 60}
# {'name': 'rect', 'x': 23, 'y': 510, 'width': 389, 'height': 57}
# {'name': 'rect', 'x': 32, 'y': 598, 'width': 378, 'height': 63}
# {'name': 'rect', 'x': 24, 'y': 671, 'width': 385, 'height': 70}
# {'name': 'rect', 'x': 24, 'y': 753, 'width': 31, 'height': 29}
# {'name': 'rect', 'x': 61, 'y': 748, 'width': 325, 'height': 54}
# {'name': 'rect', 'x': 112, 'y': 814, 'width': 214, 'height': 70}
# {'name': 'rect', 'x': 3, 'y': 8, 'width': 603, 'height': 259}
# {'name': 'rect', 'x': 1, 'y': 275, 'width': 208, 'height': 37}
# {'name': 'rect', 'x': 7, 'y': 322, 'width': 589, 'height': 76}
# {'name': 'rect', 'x': 8, 'y': 414, 'width': 586, 'height': 72}
# {'name': 'rect', 'x': 5, 'y': 487, 'width': 86, 'height': 18}
# {'name': 'rect', 'x': 4, 'y': 503, 'width': 601, 'height': 41}
# {'name': 'rect', 'x': 6, 'y': 559, 'width': 79, 'height': 20}
# {'name': 'rect', 'x': 3, 'y': 633, 'width': 57, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 573, 'width': 604, 'height': 47}
# {'name': 'rect', 'x': 3, 'y': 649, 'width': 600, 'height': 49}
# {'name': 'rect', 'x': 4, 'y': 706, 'width': 69, 'height': 22}
# {'name': 'rect', 'x': 7, 'y': 723, 'width': 311, 'height': 29}
# {'name': 'rect', 'x': 156, 'y': 8, 'width': 162, 'height': 28}
# {'name': 'rect', 'x': 188, 'y': 49, 'width': 89, 'height': 25}
# {'name': 'rect', 'x': 1, 'y': 77, 'width': 456, 'height': 14}
# {'name': 'rect', 'x': 15, 'y': 105, 'width': 80, 'height': 25}
# {'name': 'rect', 'x': 16, 'y': 137, 'width': 435, 'height': 45}
# {'name': 'rect', 'x': 17, 'y': 188, 'width': 78, 'height': 22}
# {'name': 'rect', 'x': 17, 'y': 213, 'width': 436, 'height': 42}
# {'name': 'rect', 'x': 281, 'y': 259, 'width': 167, 'height': 18}
# {'name': 'rect', 'x': 14, 'y': 272, 'width': 437, 'height': 59}
# {'name': 'rect', 'x': 19, 'y': 608, 'width': 93, 'height': 57}
# {'name': 'rect', 'x': 366, 'y': 603, 'width': 86, 'height': 63}
# {'name': 'rect', 'x': 17, 'y': 13, 'width': 498, 'height': 46}
# {'name': 'rect', 'x': 15, 'y': 85, 'width': 99, 'height': 27}
# {'name': 'rect', 'x': 20, 'y': 156, 'width': 99, 'height': 29}
# {'name': 'rect', 'x': 19, 'y': 226, 'width': 89, 'height': 29}
# {'name': 'rect', 'x': 22, 'y': 305, 'width': 65, 'height': 25}
# {'name': 'rect', 'x': 24, 'y': 380, 'width': 62, 'height': 25}
# {'name': 'rect', 'x': 26, 'y': 452, 'width': 89, 'height': 29}
# {'name': 'rect', 'x': 16, 'y': 108, 'width': 414, 'height': 50}
# {'name': 'rect', 'x': 17, 'y': 179, 'width': 408, 'height': 49}
# {'name': 'rect', 'x': 18, 'y': 256, 'width': 408, 'height': 41}
# {'name': 'rect', 'x': 23, 'y': 332, 'width': 405, 'height': 47}
# {'name': 'rect', 'x': 23, 'y': 408, 'width': 402, 'height': 43}
# {'name': 'rect', 'x': 398, 'y': 455, 'width': 33, 'height': 23}
# {'name': 'rect', 'x': 23, 'y': 476, 'width': 409, 'height': 47}
# {'name': 'rect', 'x': 23, 'y': 528, 'width': 409, 'height': 53}
# {'name': 'rect', 'x': 17, 'y': 582, 'width': 420, 'height': 43}
# {'name': 'rect', 'x': 341, 'y': 632, 'width': 94, 'height': 21}
# {'name': 'rect', 'x': 49, 'y': 26, 'width': 464, 'height': 87}
# {'name': 'rect', 'x': 53, 'y': 142, 'width': 692, 'height': 71}
# {'name': 'rect', 'x': 53, 'y': 251, 'width': 82, 'height': 32}
# {'name': 'rect', 'x': 53, 'y': 305, 'width': 100, 'height': 38}
# {'name': 'rect', 'x': 56, 'y': 370, 'width': 72, 'height': 31}
# {'name': 'rect', 'x': 171, 'y': 243, 'width': 254, 'height': 56}
# {'name': 'rect', 'x': 173, 'y': 306, 'width': 251, 'height': 50}
# {'name': 'rect', 'x': 175, 'y': 363, 'width': 250, 'height': 55}
# {'name': 'rect', 'x': 55, 'y': 412, 'width': 147, 'height': 74}
# {'name': 'rect', 'x': 37, 'y': 44, 'width': 198, 'height': 68}
# {'name': 'rect', 'x': 35, 'y': 117, 'width': 87, 'height': 29}
# {'name': 'rect', 'x': 38, 'y': 227, 'width': 82, 'height': 32}
# {'name': 'rect', 'x': 37, 'y': 339, 'width': 130, 'height': 35}
# {'name': 'rect', 'x': 40, 'y': 445, 'width': 158, 'height': 40}
# {'name': 'rect', 'x': 37, 'y': 150, 'width': 326, 'height': 68}
# {'name': 'rect', 'x': 36, 'y': 264, 'width': 323, 'height': 63}
# {'name': 'rect', 'x': 38, 'y': 371, 'width': 320, 'height': 69}
# {'name': 'rect', 'x': 41, 'y': 483, 'width': 322, 'height': 72}
# {'name': 'rect', 'x': 37, 'y': 560, 'width': 257, 'height': 69}
# {'name': 'rect', 'x': 11, 'y': 5, 'width': 106, 'height': 40}
# {'name': 'rect', 'x': 349, 'y': 6, 'width': 161, 'height': 35}
# {'name': 'rect', 'x': 10, 'y': 58, 'width': 247, 'height': 53}
# {'name': 'rect', 'x': 262, 'y': 57, 'width': 242, 'height': 50}
# {'name': 'rect', 'x': 11, 'y': 105, 'width': 145, 'height': 17}
# {'name': 'rect', 'x': 9, 'y': 127, 'width': 494, 'height': 44}
# {'name': 'rect', 'x': 8, 'y': 167, 'width': 496, 'height': 41}
# {'name': 'rect', 'x': 7, 'y': 211, 'width': 80, 'height': 46}
# {'name': 'rect', 'x': 91, 'y': 209, 'width': 242, 'height': 49}
# {'name': 'rect', 'x': 10, 'y': 257, 'width': 77, 'height': 42}
# {'name': 'rect', 'x': 93, 'y': 259, 'width': 102, 'height': 43}
# {'name': 'rect', 'x': 197, 'y': 256, 'width': 54, 'height': 49}
# {'name': 'rect', 'x': 253, 'y': 258, 'width': 71, 'height': 36}
# {'name': 'rect', 'x': 16, 'y': 303, 'width': 27, 'height': 37}
# {'name': 'rect', 'x': 98, 'y': 305, 'width': 25, 'height': 36}
# {'name': 'rect', 'x': 44, 'y': 305, 'width': 35, 'height': 26}
# {'name': 'rect', 'x': 123, 'y': 309, 'width': 67, 'height': 21}
# {'name': 'rect', 'x': 15, 'y': 354, 'width': 73, 'height': 48}
# {'name': 'rect', 'x': 324, 'y': 346, 'width': 182, 'height': 59}
# {'name': 'rect', 'x': 90, 'y': 348, 'width': 227, 'height': 61}
# {'name': 'rect', 'x': 12, 'y': 412, 'width': 208, 'height': 27}
# {'name': 'rect', 'x': 11, 'y': 441, 'width': 155, 'height': 45}
# {'name': 'rect', 'x': 99, 'y': 44, 'width': 630, 'height': 59}
# {'name': 'rect', 'x': 208, 'y': 107, 'width': 404, 'height': 35}
# {'name': 'rect', 'x': 71, 'y': 214, 'width': 131, 'height': 37}
# {'name': 'rect', 'x': 71, 'y': 308, 'width': 157, 'height': 39}
# {'name': 'rect', 'x': 68, 'y': 249, 'width': 687, 'height': 59}
# {'name': 'rect', 'x': 67, 'y': 343, 'width': 688, 'height': 60}
# {'name': 'rect', 'x': 234, 'y': 442, 'width': 357, 'height': 98}
# {'name': 'rect', 'x': 57, 'y': 581, 'width': 705, 'height': 77}
# {'name': 'rect', 'x': 201, 'y': 679, 'width': 405, 'height': 67}
# {'name': 'rect', 'x': 219, 'y': 761, 'width': 383, 'height': 37}
# {'name': 'rect', 'x': 4, 'y': 4, 'width': 152, 'height': 31}
# {'name': 'rect', 'x': 13, 'y': 57, 'width': 65, 'height': 29}
# {'name': 'rect', 'x': 13, 'y': 130, 'width': 98, 'height': 27}
# {'name': 'rect', 'x': 10, 'y': 204, 'width': 141, 'height': 27}
# {'name': 'rect', 'x': 13, 'y': 278, 'width': 30, 'height': 30}
# {'name': 'rect', 'x': 17, 'y': 346, 'width': 260, 'height': 65}
# {'name': 'rect', 'x': 277, 'y': 340, 'width': 251, 'height': 78}
# {'name': 'rect', 'x': 19, 'y': 313, 'width': 415, 'height': 26}
# {'name': 'rect', 'x': 46, 'y': 280, 'width': 106, 'height': 21}
# {'name': 'rect', 'x': 20, 'y': 85, 'width': 514, 'height': 51}
# {'name': 'rect', 'x': 22, 'y': 156, 'width': 507, 'height': 51}
# {'name': 'rect', 'x': 18, 'y': 227, 'width': 518, 'height': 56}
# {'name': 'rect', 'x': 12, 'y': 12, 'width': 505, 'height': 49}
# {'name': 'rect', 'x': 17, 'y': 87, 'width': 482, 'height': 67}
# {'name': 'rect', 'x': 18, 'y': 161, 'width': 483, 'height': 60}
# {'name': 'rect', 'x': 17, 'y': 223, 'width': 481, 'height': 63}
# {'name': 'rect', 'x': 19, 'y': 294, 'width': 478, 'height': 62}
# {'name': 'rect', 'x': 24, 'y': 361, 'width': 464, 'height': 37}
# {'name': 'rect', 'x': 23, 'y': 9, 'width': 61, 'height': 54}
# {'name': 'rect', 'x': 87, 'y': 16, 'width': 73, 'height': 43}
# {'name': 'rect', 'x': 23, 'y': 76, 'width': 270, 'height': 43}
# {'name': 'rect', 'x': 20, 'y': 152, 'width': 508, 'height': 60}
# {'name': 'rect', 'x': 22, 'y': 218, 'width': 513, 'height': 55}
# {'name': 'rect', 'x': 22, 'y': 280, 'width': 514, 'height': 61}
# {'name': 'rect', 'x': 32, 'y': 368, 'width': 15, 'height': 25}
# {'name': 'rect', 'x': 50, 'y': 369, 'width': 280, 'height': 25}
# {'name': 'rect', 'x': 26, 'y': 399, 'width': 506, 'height': 75}
# {'name': 'rect', 'x': 14, 'y': 499, 'width': 129, 'height': 30}
# {'name': 'rect', 'x': 150, 'y': 484, 'width': 108, 'height': 55}
# {'name': 'rect', 'x': 264, 'y': 480, 'width': 66, 'height': 61}
# {'name': 'rect', 'x': 17, 'y': 29, 'width': 50, 'height': 41}
# {'name': 'rect', 'x': 72, 'y': 27, 'width': 139, 'height': 48}
# {'name': 'rect', 'x': 25, 'y': 81, 'width': 46, 'height': 17}
# {'name': 'rect', 'x': 26, 'y': 104, 'width': 549, 'height': 41}
# {'name': 'rect', 'x': 21, 'y': 150, 'width': 91, 'height': 29}
# {'name': 'rect', 'x': 20, 'y': 169, 'width': 558, 'height': 52}
# {'name': 'rect', 'x': 20, 'y': 229, 'width': 117, 'height': 47}
# {'name': 'rect', 'x': 18, 'y': 306, 'width': 221, 'height': 32}
# {'name': 'rect', 'x': 19, 'y': 342, 'width': 110, 'height': 31}
# {'name': 'rect', 'x': 119, 'y': 16, 'width': 204, 'height': 35}
# {'name': 'rect', 'x': 10, 'y': 51, 'width': 405, 'height': 54}
# {'name': 'rect', 'x': 11, 'y': 119, 'width': 406, 'height': 26}
# {'name': 'rect', 'x': 34, 'y': 149, 'width': 45, 'height': 17}
# {'name': 'rect', 'x': 30, 'y': 231, 'width': 79, 'height': 25}
# {'name': 'rect', 'x': 29, 'y': 316, 'width': 81, 'height': 30}
# {'name': 'rect', 'x': 32, 'y': 164, 'width': 361, 'height': 48}
# {'name': 'rect', 'x': 30, 'y': 253, 'width': 365, 'height': 47}
# {'name': 'rect', 'x': 28, 'y': 340, 'width': 365, 'height': 48}
# {'name': 'rect', 'x': 27, 'y': 405, 'width': 38, 'height': 39}
# {'name': 'rect', 'x': 68, 'y': 405, 'width': 310, 'height': 35}
# {'name': 'rect', 'x': 124, 'y': 452, 'width': 182, 'height': 61}
# {'name': 'rect', 'x': 30, 'y': 524, 'width': 367, 'height': 46}
# {'name': 'rect', 'x': 26, 'y': 25, 'width': 361, 'height': 60}
# {'name': 'rect', 'x': 111, 'y': 89, 'width': 187, 'height': 22}
# {'name': 'rect', 'x': 48, 'y': 121, 'width': 315, 'height': 55}
# {'name': 'rect', 'x': 50, 'y': 182, 'width': 232, 'height': 42}
# {'name': 'rect', 'x': 284, 'y': 181, 'width': 83, 'height': 46}
# {'name': 'rect', 'x': 51, 'y': 218, 'width': 141, 'height': 24}
# {'name': 'rect', 'x': 53, 'y': 248, 'width': 314, 'height': 59}
# {'name': 'rect', 'x': 54, 'y': 10, 'width': 282, 'height': 89}
# {'name': 'rect', 'x': 98, 'y': 121, 'width': 90, 'height': 44}
# {'name': 'rect', 'x': 191, 'y': 121, 'width': 100, 'height': 42}
# {'name': 'rect', 'x': 78, 'y': 184, 'width': 60, 'height': 49}
# {'name': 'rect', 'x': 191, 'y': 183, 'width': 57, 'height': 55}
# {'name': 'rect', 'x': 140, 'y': 179, 'width': 51, 'height': 58}
# {'name': 'rect', 'x': 252, 'y': 181, 'width': 51, 'height': 58}
# {'name': 'rect', 'x': 177, 'y': 251, 'width': 27, 'height': 20}
# {'name': 'rect', 'x': 11, 'y': 282, 'width': 360, 'height': 56}
# {'name': 'rect', 'x': 8, 'y': 338, 'width': 364, 'height': 47}
# {'name': 'rect', 'x': 13, 'y': 383, 'width': 357, 'height': 53}
# {'name': 'rect', 'x': 17, 'y': 441, 'width': 349, 'height': 48}
# {'name': 'rect', 'x': 6, 'y': 2, 'width': 415, 'height': 30}
# {'name': 'rect', 'x': 5, 'y': 44, 'width': 699, 'height': 37}
# {'name': 'rect', 'x': 27, 'y': 109, 'width': 296, 'height': 21}
# {'name': 'rect', 'x': 5, 'y': 105, 'width': 22, 'height': 31}
# {'name': 'rect', 'x': 340, 'y': 143, 'width': 164, 'height': 46}
# {'name': 'rect', 'x': 183, 'y': 142, 'width': 159, 'height': 47}
# {'name': 'rect', 'x': 20, 'y': 146, 'width': 161, 'height': 43}
# {'name': 'rect', 'x': 19, 'y': 194, 'width': 151, 'height': 19}
# {'name': 'rect', 'x': 22, 'y': 214, 'width': 69, 'height': 12}
# {'name': 'rect', 'x': 20, 'y': 248, 'width': 71, 'height': 22}
# {'name': 'rect', 'x': 20, 'y': 291, 'width': 118, 'height': 20}
# {'name': 'rect', 'x': 8, 'y': 355, 'width': 17, 'height': 33}
# {'name': 'rect', 'x': 20, 'y': 228, 'width': 187, 'height': 33}
# {'name': 'rect', 'x': 19, 'y': 303, 'width': 180, 'height': 43}
# {'name': 'rect', 'x': 17, 'y': 268, 'width': 188, 'height': 34}
# {'name': 'rect', 'x': 28, 'y': 356, 'width': 340, 'height': 28}
# {'name': 'rect', 'x': 569, 'y': 371, 'width': 138, 'height': 54}
# {'name': 'rect', 'x': 21, 'y': 8, 'width': 299, 'height': 27}
# {'name': 'rect', 'x': 25, 'y': 33, 'width': 570, 'height': 16}
# {'name': 'rect', 'x': 22, 'y': 58, 'width': 79, 'height': 24}
# {'name': 'rect', 'x': 18, 'y': 138, 'width': 87, 'height': 23}
# {'name': 'rect', 'x': 19, 'y': 217, 'width': 135, 'height': 24}
# {'name': 'rect', 'x': 21, 'y': 300, 'width': 49, 'height': 20}
# {'name': 'rect', 'x': 21, 'y': 381, 'width': 24, 'height': 22}
# {'name': 'rect', 'x': 45, 'y': 373, 'width': 448, 'height': 27}
# {'name': 'rect', 'x': 88, 'y': 412, 'width': 257, 'height': 90}
# {'name': 'rect', 'x': 14, 'y': 410, 'width': 75, 'height': 97}
# {'name': 'rect', 'x': 22, 'y': 509, 'width': 102, 'height': 48}
# {'name': 'rect', 'x': 19, 'y': 572, 'width': 287, 'height': 26}
# {'name': 'rect', 'x': 9, 'y': 14, 'width': 190, 'height': 22}
# {'name': 'rect', 'x': 9, 'y': 41, 'width': 377, 'height': 38}
# {'name': 'rect', 'x': 8, 'y': 91, 'width': 104, 'height': 20}
# {'name': 'rect', 'x': 10, 'y': 111, 'width': 378, 'height': 47}
# {'name': 'rect', 'x': 9, 'y': 158, 'width': 371, 'height': 80}
# {'name': 'rect', 'x': 5, 'y': 258, 'width': 385, 'height': 52}
# {'name': 'rect', 'x': 5, 'y': 318, 'width': 218, 'height': 23}
# {'name': 'rect', 'x': 51, 'y': 24, 'width': 455, 'height': 39}
# {'name': 'rect', 'x': 30, 'y': 88, 'width': 490, 'height': 93}
# {'name': 'rect', 'x': 34, 'y': 185, 'width': 39, 'height': 48}
# {'name': 'rect', 'x': 75, 'y': 184, 'width': 431, 'height': 83}
# {'name': 'rect', 'x': 25, 'y': 369, 'width': 501, 'height': 99}
# {'name': 'rect', 'x': 15, 'y': 5, 'width': 190, 'height': 32}
# {'name': 'rect', 'x': 12, 'y': 46, 'width': 362, 'height': 58}
# {'name': 'rect', 'x': 14, 'y': 110, 'width': 359, 'height': 50}
# {'name': 'rect', 'x': 17, 'y': 161, 'width': 294, 'height': 22}
# {'name': 'rect', 'x': 12, 'y': 191, 'width': 364, 'height': 13}
# {'name': 'rect', 'x': 13, 'y': 209, 'width': 107, 'height': 27}
# {'name': 'rect', 'x': 7, 'y': 289, 'width': 82, 'height': 25}
# {'name': 'rect', 'x': 15, 'y': 357, 'width': 265, 'height': 27}
# {'name': 'rect', 'x': 15, 'y': 392, 'width': 78, 'height': 25}
# {'name': 'rect', 'x': 6, 'y': 464, 'width': 88, 'height': 33}
# {'name': 'rect', 'x': 10, 'y': 542, 'width': 37, 'height': 34}
# {'name': 'rect', 'x': 46, 'y': 547, 'width': 329, 'height': 43}
# {'name': 'rect', 'x': 11, 'y': 602, 'width': 366, 'height': 53}
# {'name': 'rect', 'x': 13, 'y': 660, 'width': 366, 'height': 50}
# {'name': 'rect', 'x': 14, 'y': 716, 'width': 222, 'height': 25}
# {'name': 'rect', 'x': 13, 'y': 232, 'width': 362, 'height': 51}
# {'name': 'rect', 'x': 13, 'y': 309, 'width': 362, 'height': 54}
# {'name': 'rect', 'x': 11, 'y': 414, 'width': 362, 'height': 54}
# {'name': 'rect', 'x': 13, 'y': 495, 'width': 359, 'height': 52}
# {'name': 'rect', 'x': 160, 'y': 9, 'width': 67, 'height': 61}
# {'name': 'rect', 'x': 95, 'y': 85, 'width': 196, 'height': 38}
# {'name': 'rect', 'x': 70, 'y': 123, 'width': 249, 'height': 32}
# {'name': 'rect', 'x': 20, 'y': 168, 'width': 342, 'height': 70}
# {'name': 'rect', 'x': 22, 'y': 247, 'width': 338, 'height': 60}
# {'name': 'rect', 'x': 175, 'y': 316, 'width': 32, 'height': 19}
# {'name': 'rect', 'x': 25, 'y': 344, 'width': 338, 'height': 60}
# {'name': 'rect', 'x': 34, 'y': 413, 'width': 314, 'height': 53}
# {'name': 'rect', 'x': 22, 'y': 27, 'width': 455, 'height': 62}
# {'name': 'rect', 'x': 23, 'y': 90, 'width': 454, 'height': 60}
# {'name': 'rect', 'x': 311, 'y': 153, 'width': 166, 'height': 54}
# {'name': 'rect', 'x': 44, 'y': 162, 'width': 152, 'height': 24}
# {'name': 'rect', 'x': 24, 'y': 161, 'width': 19, 'height': 23}
# {'name': 'rect', 'x': 367, 'y': 15, 'width': 207, 'height': 49}
# {'name': 'rect', 'x': 35, 'y': 75, 'width': 73, 'height': 31}
# {'name': 'rect', 'x': 37, 'y': 173, 'width': 69, 'height': 25}
# {'name': 'rect', 'x': 32, 'y': 265, 'width': 99, 'height': 25}
# {'name': 'rect', 'x': 34, 'y': 362, 'width': 70, 'height': 23}
# {'name': 'rect', 'x': 33, 'y': 456, 'width': 24, 'height': 22}
# {'name': 'rect', 'x': 58, 'y': 457, 'width': 824, 'height': 23}
# {'name': 'rect', 'x': 31, 'y': 480, 'width': 100, 'height': 20}
# {'name': 'rect', 'x': 29, 'y': 509, 'width': 167, 'height': 58}
# {'name': 'rect', 'x': 759, 'y': 509, 'width': 156, 'height': 35}
# {'name': 'rect', 'x': 36, 'y': 94, 'width': 886, 'height': 76}
# {'name': 'rect', 'x': 31, 'y': 193, 'width': 883, 'height': 71}
# {'name': 'rect', 'x': 35, 'y': 286, 'width': 879, 'height': 68}
# {'name': 'rect', 'x': 35, 'y': 375, 'width': 872, 'height': 79}
# {'name': 'rect', 'x': 8, 'y': 9, 'width': 184, 'height': 40}
# {'name': 'rect', 'x': 9, 'y': 56, 'width': 333, 'height': 96}
# {'name': 'rect', 'x': 8, 'y': 164, 'width': 346, 'height': 64}
# {'name': 'rect', 'x': 11, 'y': 237, 'width': 342, 'height': 58}
# {'name': 'rect', 'x': 12, 'y': 302, 'width': 340, 'height': 59}
# {'name': 'rect', 'x': 10, 'y': 367, 'width': 343, 'height': 63}
# {'name': 'rect', 'x': 10, 'y': 452, 'width': 132, 'height': 27}
# {'name': 'rect', 'x': 8, 'y': 485, 'width': 329, 'height': 82}
# {'name': 'rect', 'x': 10, 'y': 570, 'width': 34, 'height': 36}
# {'name': 'rect', 'x': 11, 'y': 621, 'width': 34, 'height': 35}
# {'name': 'rect', 'x': 89, 'y': 567, 'width': 32, 'height': 38}
# {'name': 'rect', 'x': 44, 'y': 574, 'width': 28, 'height': 20}
# {'name': 'rect', 'x': 122, 'y': 574, 'width': 39, 'height': 22}
# {'name': 'rect', 'x': 34, 'y': 618, 'width': 311, 'height': 98}
# {'name': 'rect', 'x': 67, 'y': 732, 'width': 233, 'height': 84}
# {'name': 'rect', 'x': 12, 'y': 13, 'width': 73, 'height': 27}
# {'name': 'rect', 'x': 12, 'y': 41, 'width': 193, 'height': 30}
# {'name': 'rect', 'x': 11, 'y': 81, 'width': 331, 'height': 50}
# {'name': 'rect', 'x': 13, 'y': 136, 'width': 325, 'height': 30}
# {'name': 'rect', 'x': 15, 'y': 169, 'width': 330, 'height': 54}
# {'name': 'rect', 'x': 13, 'y': 220, 'width': 330, 'height': 56}
# {'name': 'rect', 'x': 14, 'y': 278, 'width': 329, 'height': 46}
# {'name': 'rect', 'x': 289, 'y': 322, 'width': 59, 'height': 16}
# {'name': 'rect', 'x': 39, 'y': 12, 'width': 234, 'height': 39}
# {'name': 'rect', 'x': 38, 'y': 58, 'width': 199, 'height': 26}
# {'name': 'rect', 'x': 38, 'y': 89, 'width': 580, 'height': 22}
# {'name': 'rect', 'x': 40, 'y': 116, 'width': 572, 'height': 55}
# {'name': 'rect', 'x': 43, 'y': 176, 'width': 569, 'height': 59}
# {'name': 'rect', 'x': 46, 'y': 239, 'width': 279, 'height': 59}
# {'name': 'rect', 'x': 334, 'y': 235, 'width': 279, 'height': 64}
# {'name': 'rect', 'x': 43, 'y': 294, 'width': 280, 'height': 66}
# {'name': 'rect', 'x': 247, 'y': 116, 'width': 273, 'height': 57}
# {'name': 'rect', 'x': 252, 'y': 173, 'width': 280, 'height': 24}
# {'name': 'rect', 'x': 248, 'y': 235, 'width': 281, 'height': 34}
# {'name': 'rect', 'x': 73, 'y': 298, 'width': 92, 'height': 39}
# {'name': 'rect', 'x': 75, 'y': 395, 'width': 57, 'height': 34}
# {'name': 'rect', 'x': 391, 'y': 299, 'width': 85, 'height': 36}
# {'name': 'rect', 'x': 391, 'y': 397, 'width': 87, 'height': 33}
# {'name': 'rect', 'x': 195, 'y': 9, 'width': 394, 'height': 56}
# {'name': 'rect', 'x': 250, 'y': 493, 'width': 271, 'height': 51}
# {'name': 'rect', 'x': 146, 'y': 584, 'width': 490, 'height': 30}
# {'name': 'rect', 'x': 391, 'y': 331, 'width': 314, 'height': 57}
# {'name': 'rect', 'x': 72, 'y': 333, 'width': 314, 'height': 57}
# {'name': 'rect', 'x': 72, 'y': 425, 'width': 314, 'height': 57}
# {'name': 'rect', 'x': 391, 'y': 425, 'width': 314, 'height': 57}
# {'name': 'rect', 'x': 10, 'y': 0, 'width': 335, 'height': 47}
# {'name': 'rect', 'x': 23, 'y': 94, 'width': 136, 'height': 27}
# {'name': 'rect', 'x': 20, 'y': 186, 'width': 52, 'height': 21}
# {'name': 'rect', 'x': 27, 'y': 278, 'width': 134, 'height': 22}
# {'name': 'rect', 'x': 26, 'y': 372, 'width': 78, 'height': 19}
# {'name': 'rect', 'x': 22, 'y': 456, 'width': 121, 'height': 27}
# {'name': 'rect', 'x': 24, 'y': 548, 'width': 89, 'height': 26}
# {'name': 'rect', 'x': 22, 'y': 111, 'width': 535, 'height': 66}
# {'name': 'rect', 'x': 22, 'y': 201, 'width': 535, 'height': 70}
# {'name': 'rect', 'x': 26, 'y': 290, 'width': 531, 'height': 67}
# {'name': 'rect', 'x': 21, 'y': 383, 'width': 538, 'height': 67}
# {'name': 'rect', 'x': 26, 'y': 478, 'width': 530, 'height': 62}
# {'name': 'rect', 'x': 23, 'y': 568, 'width': 533, 'height': 63}
# {'name': 'rect', 'x': 19, 'y': 666, 'width': 30, 'height': 30}
# {'name': 'rect', 'x': 48, 'y': 666, 'width': 508, 'height': 55}
# {'name': 'rect', 'x': 250, 'y': 782, 'width': 218, 'height': 28}
# {'name': 'rect', 'x': 17, 'y': 763, 'width': 219, 'height': 70}
# {'name': 'rect', 'x': 350, 'y': 77, 'width': 222, 'height': 71}
# {'name': 'rect', 'x': 367, 'y': 157, 'width': 187, 'height': 27}
# {'name': 'rect', 'x': 529, 'y': 410, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 54, 'y': 263, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 54, 'y': 338, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 54, 'y': 408, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 529, 'y': 264, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 529, 'y': 337, 'width': 344, 'height': 71}
# {'name': 'rect', 'x': 289, 'y': 481, 'width': 348, 'height': 67}
# {'name': 'rect', 'x': 10, 'y': 8, 'width': 140, 'height': 34}
# {'name': 'rect', 'x': 10, 'y': 56, 'width': 79, 'height': 24}
# {'name': 'rect', 'x': 203, 'y': 54, 'width': 77, 'height': 24}
# {'name': 'rect', 'x': 5, 'y': 127, 'width': 76, 'height': 25}
# {'name': 'rect', 'x': 11, 'y': 193, 'width': 31, 'height': 18}
# {'name': 'rect', 'x': 8, 'y': 263, 'width': 152, 'height': 24}
# {'name': 'rect', 'x': 11, 'y': 331, 'width': 71, 'height': 25}
# {'name': 'rect', 'x': 5, 'y': 402, 'width': 110, 'height': 20}
# {'name': 'rect', 'x': 9, 'y': 452, 'width': 395, 'height': 54}
# {'name': 'rect', 'x': 9, 'y': 585, 'width': 387, 'height': 39}
# {'name': 'rect', 'x': 5, 'y': 70, 'width': 195, 'height': 52}
# {'name': 'rect', 'x': 203, 'y': 70, 'width': 195, 'height': 52}
# {'name': 'rect', 'x': 38, 'y': 221, 'width': 37, 'height': 23}
# {'name': 'rect', 'x': 111, 'y': 220, 'width': 56, 'height': 25}
# {'name': 'rect', 'x': 293, 'y': 145, 'width': 109, 'height': 44}
# {'name': 'rect', 'x': 4, 'y': 145, 'width': 102, 'height': 44}
# {'name': 'rect', 'x': 106, 'y': 145, 'width': 191, 'height': 44}
# {'name': 'rect', 'x': 10, 'y': 216, 'width': 30, 'height': 32}
# {'name': 'rect', 'x': 89, 'y': 221, 'width': 22, 'height': 26}
# {'name': 'rect', 'x': 10, 'y': 279, 'width': 276, 'height': 48}
# {'name': 'rect', 'x': 288, 'y': 274, 'width': 106, 'height': 59}
# {'name': 'rect', 'x': 7, 'y': 347, 'width': 392, 'height': 50}
# {'name': 'rect', 'x': 154, 'y': 420, 'width': 248, 'height': 42}
# {'name': 'rect', 'x': 9, 'y': 425, 'width': 145, 'height': 36}
# {'name': 'rect', 'x': 10, 'y': 529, 'width': 100, 'height': 50}
# {'name': 'rect', 'x': 4, 'y': 508, 'width': 403, 'height': 17}
# {'name': 'rect', 'x': 27, 'y': 14, 'width': 312, 'height': 53}
# {'name': 'rect', 'x': 8, 'y': 78, 'width': 109, 'height': 67}
# {'name': 'rect', 'x': 122, 'y': 79, 'width': 111, 'height': 65}
# {'name': 'rect', 'x': 233, 'y': 75, 'width': 114, 'height': 75}
# {'name': 'rect', 'x': 11, 'y': 159, 'width': 333, 'height': 56}
# {'name': 'rect', 'x': 13, 'y': 213, 'width': 331, 'height': 59}
# {'name': 'rect', 'x': 14, 'y': 264, 'width': 331, 'height': 64}
# {'name': 'rect', 'x': 66, 'y': 332, 'width': 264, 'height': 93}
# {'name': 'rect', 'x': 9, 'y': 328, 'width': 57, 'height': 98}
# {'name': 'rect', 'x': 9, 'y': 429, 'width': 331, 'height': 131}
# {'name': 'rect', 'x': 11, 'y': 566, 'width': 332, 'height': 58}
# {'name': 'rect', 'x': 59, 'y': 25, 'width': 605, 'height': 152}
# {'name': 'rect', 'x': 288, 'y': 213, 'width': 138, 'height': 42}
# {'name': 'rect', 'x': 44, 'y': 511, 'width': 21, 'height': 22}
# {'name': 'rect', 'x': 67, 'y': 511, 'width': 172, 'height': 22}
# {'name': 'rect', 'x': 43, 'y': 257, 'width': 624, 'height': 54}
# {'name': 'rect', 'x': 41, 'y': 537, 'width': 625, 'height': 48}
# {'name': 'rect', 'x': 41, 'y': 311, 'width': 625, 'height': 48}
# {'name': 'rect', 'x': 41, 'y': 361, 'width': 625, 'height': 48}
# {'name': 'rect', 'x': 41, 'y': 411, 'width': 625, 'height': 48}
# {'name': 'rect', 'x': 41, 'y': 457, 'width': 625, 'height': 48}
# {'name': 'rect', 'x': 174, 'y': 30, 'width': 233, 'height': 56}
# {'name': 'rect', 'x': 23, 'y': 363, 'width': 533, 'height': 87}
# {'name': 'rect', 'x': 18, 'y': 105, 'width': 272, 'height': 75}
# {'name': 'rect', 'x': 297, 'y': 106, 'width': 261, 'height': 74}
# {'name': 'rect', 'x': 20, 'y': 192, 'width': 537, 'height': 71}
# {'name': 'rect', 'x': 24, 'y': 280, 'width': 533, 'height': 66}
# {'name': 'rect', 'x': 199, 'y': 33, 'width': 55, 'height': 51}
# {'name': 'rect', 'x': 257, 'y': 32, 'width': 133, 'height': 50}
# {'name': 'rect', 'x': 98, 'y': 309, 'width': 398, 'height': 53}
# {'name': 'rect', 'x': 98, 'y': 129, 'width': 398, 'height': 53}
# {'name': 'rect', 'x': 98, 'y': 188, 'width': 398, 'height': 53}
# {'name': 'rect', 'x': 98, 'y': 248, 'width': 398, 'height': 53}
# {'name': 'rect', 'x': 214, 'y': 368, 'width': 178, 'height': 27}
# {'name': 'rect', 'x': 243, 'y': 452, 'width': 108, 'height': 63}
# {'name': 'rect', 'x': 245, 'y': 520, 'width': 107, 'height': 13}
# {'name': 'rect', 'x': 185, 'y': 13, 'width': 191, 'height': 47}
# {'name': 'rect', 'x': 6, 'y': 72, 'width': 268, 'height': 73}
# {'name': 'rect', 'x': 283, 'y': 71, 'width': 273, 'height': 78}
# {'name': 'rect', 'x': 271, 'y': 160, 'width': 19, 'height': 20}
# {'name': 'rect', 'x': 5, 'y': 158, 'width': 260, 'height': 24}
# {'name': 'rect', 'x': 295, 'y': 159, 'width': 256, 'height': 21}
# {'name': 'rect', 'x': 6, 'y': 190, 'width': 270, 'height': 78}
# {'name': 'rect', 'x': 282, 'y': 186, 'width': 272, 'height': 84}
# {'name': 'rect', 'x': 7, 'y': 277, 'width': 545, 'height': 76}
# {'name': 'rect', 'x': 8, 'y': 361, 'width': 547, 'height': 75}
# {'name': 'rect', 'x': 378, 'y': 444, 'width': 175, 'height': 74}
# {'name': 'rect', 'x': 10, 'y': 463, 'width': 244, 'height': 33}
# {'name': 'rect', 'x': 8, 'y': 2, 'width': 142, 'height': 25}
# {'name': 'rect', 'x': 5, 'y': 44, 'width': 475, 'height': 38}
# {'name': 'rect', 'x': 25, 'y': 99, 'width': 175, 'height': 34}
# {'name': 'rect', 'x': 279, 'y': 101, 'width': 168, 'height': 34}
# {'name': 'rect', 'x': 260, 'y': 96, 'width': 14, 'height': 330}
# {'name': 'rect', 'x': 23, 'y': 423, 'width': 426, 'height': 30}
# {'name': 'rect', 'x': 281, 'y': 235, 'width': 111, 'height': 59}
# {'name': 'rect', 'x': 21, 'y': 341, 'width': 123, 'height': 52}
# {'name': 'rect', 'x': 28, 'y': 290, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 280, 'y': 189, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 28, 'y': 192, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 28, 'y': 240, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 28, 'y': 138, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 280, 'y': 138, 'width': 223, 'height': 51}
# {'name': 'rect', 'x': 27, 'y': 33, 'width': 225, 'height': 62}
# {'name': 'rect', 'x': 32, 'y': 101, 'width': 78, 'height': 29}
# {'name': 'rect', 'x': 29, 'y': 209, 'width': 83, 'height': 30}
# {'name': 'rect', 'x': 35, 'y': 322, 'width': 117, 'height': 33}
# {'name': 'rect', 'x': 33, 'y': 441, 'width': 150, 'height': 25}
# {'name': 'rect', 'x': 29, 'y': 542, 'width': 257, 'height': 71}
# {'name': 'rect', 'x': 32, 'y': 128, 'width': 321, 'height': 73}
# {'name': 'rect', 'x': 30, 'y': 243, 'width': 332, 'height': 70}
# {'name': 'rect', 'x': 34, 'y': 352, 'width': 319, 'height': 73}
# {'name': 'rect', 'x': 31, 'y': 463, 'width': 320, 'height': 73}
# {'name': 'rect', 'x': 24, 'y': 14, 'width': 207, 'height': 69}
# {'name': 'rect', 'x': 21, 'y': 92, 'width': 117, 'height': 19}
# {'name': 'rect', 'x': 15, 'y': 157, 'width': 447, 'height': 88}
# {'name': 'rect', 'x': 13, 'y': 324, 'width': 452, 'height': 77}
# {'name': 'rect', 'x': 13, 'y': 245, 'width': 452, 'height': 77}
# {'name': 'rect', 'x': 19, 'y': 412, 'width': 40, 'height': 38}
# {'name': 'rect', 'x': 59, 'y': 412, 'width': 300, 'height': 37}
# {'name': 'rect', 'x': 19, 'y': 458, 'width': 281, 'height': 82}
# {'name': 'rect', 'x': 20, 'y': 560, 'width': 248, 'height': 24}
# {'name': 'rect', 'x': 5, 'y': 4, 'width': 276, 'height': 32}
# {'name': 'rect', 'x': 5, 'y': 41, 'width': 329, 'height': 54}
# {'name': 'rect', 'x': 7, 'y': 95, 'width': 328, 'height': 52}
# {'name': 'rect', 'x': 6, 'y': 147, 'width': 327, 'height': 54}
# {'name': 'rect', 'x': 6, 'y': 199, 'width': 328, 'height': 57}
# {'name': 'rect', 'x': 5, 'y': 255, 'width': 329, 'height': 58}
# {'name': 'rect', 'x': 4, 'y': 323, 'width': 98, 'height': 27}
# {'name': 'rect', 'x': 126, 'y': 318, 'width': 40, 'height': 30}
# {'name': 'rect', 'x': 189, 'y': 321, 'width': 64, 'height': 28}
# {'name': 'rect', 'x': 284, 'y': 322, 'width': 39, 'height': 26}
# {'name': 'rect', 'x': 105, 'y': 320, 'width': 24, 'height': 26}
# {'name': 'rect', 'x': 259, 'y': 318, 'width': 27, 'height': 32}
# {'name': 'rect', 'x': 168, 'y': 318, 'width': 23, 'height': 32}
# {'name': 'rect', 'x': 4, 'y': 361, 'width': 332, 'height': 57}
# {'name': 'rect', 'x': 7, 'y': 580, 'width': 327, 'height': 11}
# {'name': 'rect', 'x': 2, 'y': 493, 'width': 331, 'height': 56}
# {'name': 'rect', 'x': 2, 'y': 438, 'width': 331, 'height': 56}
# {'name': 'rect', 'x': 7, 'y': 422, 'width': 327, 'height': 11}
# {'name': 'rect', 'x': 66, 'y': 548, 'width': 209, 'height': 20}
# {'name': 'rect', 'x': 6, 'y': 595, 'width': 330, 'height': 59}
# {'name': 'rect', 'x': 5, 'y': 662, 'width': 30, 'height': 31}
# {'name': 'rect', 'x': 32, 'y': 662, 'width': 299, 'height': 31}
# {'name': 'rect', 'x': 7, 'y': 705, 'width': 60, 'height': 92}
# {'name': 'rect', 'x': 66, 'y': 702, 'width': 258, 'height': 96}
# {'name': 'rect', 'x': 88, 'y': 806, 'width': 161, 'height': 47}
# {'name': 'rect', 'x': 252, 'y': 18, 'width': 162, 'height': 67}
# {'name': 'rect', 'x': 23, 'y': 127, 'width': 46, 'height': 45}
# {'name': 'rect', 'x': 23, 'y': 300, 'width': 47, 'height': 50}
# {'name': 'rect', 'x': 67, 'y': 112, 'width': 537, 'height': 71}
# {'name': 'rect', 'x': 314, 'y': 208, 'width': 35, 'height': 26}
# {'name': 'rect', 'x': 105, 'y': 212, 'width': 171, 'height': 18}
# {'name': 'rect', 'x': 383, 'y': 206, 'width': 180, 'height': 28}
# {'name': 'rect', 'x': 70, 'y': 265, 'width': 135, 'height': 32}
# {'name': 'rect', 'x': 70, 'y': 294, 'width': 530, 'height': 68}
# {'name': 'rect', 'x': 72, 'y': 377, 'width': 90, 'height': 28}
# {'name': 'rect', 'x': 69, 'y': 407, 'width': 534, 'height': 66}
# {'name': 'rect', 'x': 68, 'y': 478, 'width': 538, 'height': 76}
# {'name': 'rect', 'x': 257, 'y': 597, 'width': 156, 'height': 36}
# {'name': 'rect', 'x': 197, 'y': 644, 'width': 273, 'height': 32}
# {'name': 'rect', 'x': 0, 'y': 11, 'width': 136, 'height': 37}
# {'name': 'rect', 'x': 37, 'y': 74, 'width': 270, 'height': 47}
# {'name': 'rect', 'x': 35, 'y': 121, 'width': 272, 'height': 44}
# {'name': 'rect', 'x': 114, 'y': 170, 'width': 106, 'height': 34}
# {'name': 'rect', 'x': 83, 'y': 215, 'width': 165, 'height': 26}
# {'name': 'rect', 'x': 15, 'y': 120, 'width': 400, 'height': 22}
# {'name': 'rect', 'x': 284, 'y': 39, 'width': 70, 'height': 73}
# {'name': 'rect', 'x': 86, 'y': 39, 'width': 70, 'height': 73}
# {'name': 'rect', 'x': 151, 'y': 39, 'width': 70, 'height': 73}
# {'name': 'rect', 'x': 218, 'y': 39, 'width': 70, 'height': 73}
# {'name': 'rect', 'x': 19, 'y': 16, 'width': 400, 'height': 22}
# {'name': 'rect', 'x': 22, 'y': 332, 'width': 399, 'height': 64}
# {'name': 'rect', 'x': 22, 'y': 158, 'width': 399, 'height': 64}
# {'name': 'rect', 'x': 22, 'y': 215, 'width': 399, 'height': 64}
# {'name': 'rect', 'x': 22, 'y': 272, 'width': 399, 'height': 64}
# {'name': 'rect', 'x': 22, 'y': 398, 'width': 60, 'height': 19}
# {'name': 'rect', 'x': 272, 'y': 423, 'width': 142, 'height': 50}
# {'name': 'rect', 'x': 23, 'y': 422, 'width': 107, 'height': 50}
# {'name': 'rect', 'x': 132, 'y': 422, 'width': 142, 'height': 50}
# {'name': 'rect', 'x': 22, 'y': 479, 'width': 58, 'height': 17}
# {'name': 'rect', 'x': 20, 'y': 577, 'width': 401, 'height': 59}
# {'name': 'rect', 'x': 20, 'y': 562, 'width': 75, 'height': 13}
# {'name': 'rect', 'x': 21, 'y': 496, 'width': 401, 'height': 59}
# {'name': 'rect', 'x': 25, 'y': 641, 'width': 319, 'height': 21}
# {'name': 'rect', 'x': 26, 'y': 660, 'width': 392, 'height': 57}
# {'name': 'rect', 'x': 24, 'y': 727, 'width': 397, 'height': 65}
# {'name': 'rect', 'x': 52, 'y': 13, 'width': 212, 'height': 32}
# {'name': 'rect', 'x': 62, 'y': 49, 'width': 198, 'height': 26}
# {'name': 'rect', 'x': 107, 'y': 92, 'width': 115, 'height': 13}
# {'name': 'rect', 'x': 52, 'y': 117, 'width': 101, 'height': 25}
# {'name': 'rect', 'x': 50, 'y': 210, 'width': 82, 'height': 22}
# {'name': 'rect', 'x': 65, 'y': 381, 'width': 168, 'height': 26}
# {'name': 'rect', 'x': 54, 'y': 307, 'width': 222, 'height': 65}
# {'name': 'rect', 'x': 55, 'y': 140, 'width': 221, 'height': 51}
# {'name': 'rect', 'x': 54, 'y': 231, 'width': 224, 'height': 50}
# {'name': 'rect', 'x': 5, 'y': 128, 'width': 412, 'height': 59}
# {'name': 'rect', 'x': 5, 'y': 19, 'width': 412, 'height': 59}
# {'name': 'rect', 'x': 5, 'y': 77, 'width': 412, 'height': 59}
# {'name': 'rect', 'x': 6, 'y': 196, 'width': 413, 'height': 58}
# {'name': 'rect', 'x': 64, 'y': 42, 'width': 222, 'height': 47}
# {'name': 'rect', 'x': 282, 'y': 30, 'width': 52, 'height': 37}
# {'name': 'rect', 'x': 75, 'y': 96, 'width': 107, 'height': 27}
# {'name': 'rect', 'x': 102, 'y': 151, 'width': 84, 'height': 41}
# {'name': 'rect', 'x': 195, 'y': 153, 'width': 88, 'height': 34}
# {'name': 'rect', 'x': 255, 'y': 212, 'width': 55, 'height': 56}
# {'name': 'rect', 'x': 88, 'y': 212, 'width': 55, 'height': 56}
# {'name': 'rect', 'x': 145, 'y': 212, 'width': 55, 'height': 56}
# {'name': 'rect', 'x': 198, 'y': 212, 'width': 55, 'height': 56}
# {'name': 'rect', 'x': 21, 'y': 183, 'width': 357, 'height': 15}
# {'name': 'rect', 'x': 187, 'y': 283, 'width': 23, 'height': 17}
# {'name': 'rect', 'x': 21, 'y': 314, 'width': 355, 'height': 52}
# {'name': 'rect', 'x': 23, 'y': 369, 'width': 354, 'height': 48}
# {'name': 'rect', 'x': 23, 'y': 421, 'width': 349, 'height': 47}
# {'name': 'rect', 'x': 67, 'y': 477, 'width': 260, 'height': 25}
# {'name': 'rect', 'x': 64, 'y': 42, 'width': 222, 'height': 47}
# ...
# {'name': 'rect', 'x': 20, 'y': 345, 'width': 154, 'height': 40}
# {'name': 'rect', 'x': 22, 'y': 163, 'width': 292, 'height': 40}
# {'name': 'rect', 'x': 23, 'y': 203, 'width': 292, 'height': 40}
# {'name': 'rect', 'x': 21, 'y': 244, 'width': 292, 'height': 40}
# {'name': 'rect', 'x': 20, 'y': 284, 'width': 292, 'height': 40}
# {'name': 'rect', 'x': 23, 'y': 388, 'width': 239, 'height': 16}
# {'name': 'rect', 'x': 12, 'y': 15, 'width': 114, 'height': 44}
# {'name': 'rect', 'x': 10, 'y': 190, 'width': 349, 'height': 57}
# {'name': 'rect', 'x': 11, 'y': 66, 'width': 349, 'height': 57}
# {'name': 'rect', 'x': 37, 'y': 252, 'width': 318, 'height': 57}
# {'name': 'rect', 'x': 10, 'y': 128, 'width': 349, 'height': 57}
# {'name': 'rect', 'x': 12, 'y': 335, 'width': 349, 'height': 57}
# {'name': 'rect', 'x': 14, 'y': 253, 'width': 25, 'height': 27}
# {'name': 'rect', 'x': 9, 'y': 395, 'width': 342, 'height': 55}
# {'name': 'rect', 'x': 4, 'y': 459, 'width': 358, 'height': 22}
# {'name': 'rect', 'x': 9, 'y': 492, 'width': 349, 'height': 58}
# {'name': 'rect', 'x': 13, 'y': 553, 'width': 324, 'height': 74}
# {'name': 'rect', 'x': 8, 'y': 6, 'width': 195, 'height': 34}
# {'name': 'rect', 'x': 11, 'y': 45, 'width': 108, 'height': 17}
# {'name': 'rect', 'x': 9, 'y': 296, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 9, 'y': 65, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 9, 'y': 96, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 9, 'y': 127, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 9, 'y': 162, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 9, 'y': 193, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 10, 'y': 225, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 10, 'y': 258, 'width': 194, 'height': 35}
# {'name': 'rect', 'x': 146, 'y': 19, 'width': 191, 'height': 60}
# {'name': 'rect', 'x': 40, 'y': 333, 'width': 404, 'height': 73}
# {'name': 'rect', 'x': 41, 'y': 145, 'width': 404, 'height': 73}
# {'name': 'rect', 'x': 226, 'y': 299, 'width': 216, 'height': 24}
# {'name': 'rect', 'x': 45, 'y': 218, 'width': 404, 'height': 73}
# {'name': 'rect', 'x': 8, 'y': 8, 'width': 85, 'height': 33}
# {'name': 'rect', 'x': 6, 'y': 232, 'width': 337, 'height': 57}
# {'name': 'rect', 'x': 10, 'y': 63, 'width': 331, 'height': 76}
# {'name': 'rect', 'x': 9, 'y': 143, 'width': 331, 'height': 76}
# {'name': 'rect', 'x': 57, 'y': 8, 'width': 87, 'height': 21}
# {'name': 'rect', 'x': 14, 'y': 201, 'width': 108, 'height': 38}
# {'name': 'rect', 'x': 12, 'y': 42, 'width': 175, 'height': 38}
# {'name': 'rect', 'x': 13, 'y': 85, 'width': 175, 'height': 38}
# {'name': 'rect', 'x': 14, 'y': 123, 'width': 175, 'height': 38}
# {'name': 'rect', 'x': 16, 'y': 163, 'width': 175, 'height': 38}
# {'name': 'rect', 'x': 123, 'y': 202, 'width': 66, 'height': 35}
# {'name': 'rect', 'x': 15, 'y': 235, 'width': 17, 'height': 23}
# {'name': 'rect', 'x': 31, 'y': 233, 'width': 114, 'height': 18}
# {'name': 'rect', 'x': 14, 'y': 256, 'width': 173, 'height': 44}
# {'name': 'rect', 'x': 15, 'y': 311, 'width': 119, 'height': 21}
# {'name': 'rect', 'x': 142, 'y': 317, 'width': 46, 'height': 12}
# {'name': 'rect', 'x': 13, 'y': 303, 'width': 179, 'height': 11}
# {'name': 'rect', 'x': 131, 'y': 21, 'width': 273, 'height': 215}
# {'name': 'rect', 'x': 210, 'y': 246, 'width': 121, 'height': 58}
# {'name': 'rect', 'x': 21, 'y': 635, 'width': 494, 'height': 108}
# {'name': 'rect', 'x': 18, 'y': 398, 'width': 494, 'height': 95}
# {'name': 'rect', 'x': 15, 'y': 499, 'width': 494, 'height': 95}
# {'name': 'rect', 'x': 92, 'y': 780, 'width': 315, 'height': 33}
# {'name': 'rect', 'x': 83, 'y': 18, 'width': 344, 'height': 41}
# {'name': 'rect', 'x': 139, 'y': 78, 'width': 233, 'height': 32}
# {'name': 'rect', 'x': 4, 'y': 183, 'width': 73, 'height': 47}
# {'name': 'rect', 'x': 86, 'y': 179, 'width': 423, 'height': 53}
# {'name': 'rect', 'x': 4, 'y': 129, 'width': 73, 'height': 47}
# {'name': 'rect', 'x': 86, 'y': 125, 'width': 423, 'height': 53}
# {'name': 'rect', 'x': 12, 'y': 295, 'width': 491, 'height': 28}
# {'name': 'rect', 'x': 376, 'y': 229, 'width': 122, 'height': 42}
# {'name': 'rect', 'x': 87, 'y': 234, 'width': 102, 'height': 50}
# {'name': 'rect', 'x': 284, 'y': 332, 'width': 49, 'height': 55}
# {'name': 'rect', 'x': 169, 'y': 332, 'width': 49, 'height': 55}
# {'name': 'rect', 'x': 228, 'y': 333, 'width': 49, 'height': 55}
# {'name': 'rect', 'x': 42, 'y': 333, 'width': 338, 'height': 77}
# {'name': 'rect', 'x': 39, 'y': 34, 'width': 338, 'height': 77}
# {'name': 'rect', 'x': 40, 'y': 106, 'width': 338, 'height': 77}
# {'name': 'rect', 'x': 46, 'y': 258, 'width': 338, 'height': 77}
# {'name': 'rect', 'x': 40, 'y': 106, 'width': 338, 'height': 77}
# {'name': 'rect', 'x': 13, 'y': 190, 'width': 383, 'height': 60}
# {'name': 'rect', 'x': 42, 'y': 413, 'width': 335, 'height': 62}
# {'name': 'rect', 'x': 19, 'y': 5, 'width': 202, 'height': 41}
# {'name': 'rect', 'x': 13, 'y': 223, 'width': 292, 'height': 54}
# {'name': 'rect', 'x': 12, 'y': 56, 'width': 292, 'height': 54}
# {'name': 'rect', 'x': 12, 'y': 113, 'width': 292, 'height': 54}
# {'name': 'rect', 'x': 11, 'y': 166, 'width': 292, 'height': 54}
# {'name': 'rect', 'x': 59, 'y': 290, 'width': 198, 'height': 36}
# {'name': 'rect', 'x': 101, 'y': 330, 'width': 117, 'height': 54}
# {'name': 'rect', 'x': 68, 'y': 404, 'width': 179, 'height': 24}
# {'name': 'rect', 'x': 2, 'y': 154, 'width': 408, 'height': 83}
# {'name': 'rect', 'x': 3, 'y': 70, 'width': 408, 'height': 65}
# {'name': 'rect', 'x': 8, 'y': 169, 'width': 240, 'height': 49}
# {'name': 'rect', 'x': 9, 'y': 19, 'width': 240, 'height': 49}
# {'name': 'rect', 'x': 11, 'y': 69, 'width': 240, 'height': 49}
# {'name': 'rect', 'x': 10, 'y': 117, 'width': 240, 'height': 49}
# {'name': 'rect', 'x': 81, 'y': 228, 'width': 98, 'height': 53}
# {'name': 'rect', 'x': 92, 'y': 4, 'width': 114, 'height': 80}
# {'name': 'rect', 'x': 6, 'y': 338, 'width': 269, 'height': 47}
# {'name': 'rect', 'x': 8, 'y': 121, 'width': 269, 'height': 57}
# {'name': 'rect', 'x': 8, 'y': 178, 'width': 269, 'height': 57}
# {'name': 'rect', 'x': 7, 'y': 229, 'width': 269, 'height': 57}
# {'name': 'rect', 'x': 7, 'y': 282, 'width': 269, 'height': 57}
# {'name': 'rect', 'x': 58, 'y': 386, 'width': 170, 'height': 15}
# {'name': 'rect', 'x': 16, 'y': 348, 'width': 442, 'height': 95}
# {'name': 'rect', 'x': 16, 'y': 23, 'width': 442, 'height': 95}
# {'name': 'rect', 'x': 12, 'y': 132, 'width': 442, 'height': 95}
# {'name': 'rect', 'x': 13, 'y': 239, 'width': 442, 'height': 95}
# {'name': 'rect', 'x': 6, 'y': 6, 'width': 267, 'height': 53}
# {'name': 'rect', 'x': 7, 'y': 71, 'width': 464, 'height': 57}
# {'name': 'rect', 'x': 11, 'y': 347, 'width': 96, 'height': 34}
# {'name': 'rect', 'x': 13, 'y': 377, 'width': 496, 'height': 71}
# {'name': 'rect', 'x': 6, 'y': 141, 'width': 96, 'height': 34}
# {'name': 'rect', 'x': 8, 'y': 175, 'width': 246, 'height': 67}
# {'name': 'rect', 'x': 264, 'y': 140, 'width': 96, 'height': 34}
# {'name': 'rect', 'x': 266, 'y': 174, 'width': 246, 'height': 67}
# {'name': 'rect', 'x': 11, 'y': 248, 'width': 96, 'height': 34}
# {'name': 'rect', 'x': 13, 'y': 278, 'width': 496, 'height': 71}
# {'name': 'rect', 'x': 8, 'y': 446, 'width': 30, 'height': 35}
# {'name': 'rect', 'x': 41, 'y': 445, 'width': 282, 'height': 34}
# {'name': 'rect', 'x': 8, 'y': 521, 'width': 258, 'height': 39}
# {'name': 'rect', 'x': 292, 'y': 499, 'width': 219, 'height': 79}
# {'name': 'rect', 'x': 111, 'y': 14, 'width': 230, 'height': 51}
# {'name': 'rect', 'x': 88, 'y': 78, 'width': 300, 'height': 96}
# {'name': 'rect', 'x': 27, 'y': 627, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 22, 'y': 201, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 19, 'y': 257, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 26, 'y': 573, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 17, 'y': 543, 'width': 160, 'height': 36}
# {'name': 'rect', 'x': 179, 'y': 336, 'width': 94, 'height': 22}
# {'name': 'rect', 'x': 25, 'y': 390, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 16, 'y': 360, 'width': 160, 'height': 36}
# {'name': 'rect', 'x': 25, 'y': 478, 'width': 416, 'height': 59}
# {'name': 'rect', 'x': 16, 'y': 448, 'width': 160, 'height': 36}
# {'name': 'rect', 'x': 58, 'y': 685, 'width': 353, 'height': 30}
# {'name': 'rect', 'x': 94, 'y': 729, 'width': 267, 'height': 29}
# {'name': 'rect', 'x': 167, 'y': 766, 'width': 124, 'height': 25}
# {'name': 'rect', 'x': 16, 'y': 24, 'width': 1106, 'height': 100}
# {'name': 'rect', 'x': 14, 'y': 144, 'width': 585, 'height': 105}
# {'name': 'rect', 'x': 14, 'y': 245, 'width': 644, 'height': 58}
# {'name': 'rect', 'x': 610, 'y': 330, 'width': 587, 'height': 103}
# {'name': 'rect', 'x': 12, 'y': 333, 'width': 587, 'height': 103}
# {'name': 'rect', 'x': 14, 'y': 703, 'width': 1183, 'height': 106}
# {'name': 'rect', 'x': 13, 'y': 454, 'width': 1183, 'height': 106}
# {'name': 'rect', 'x': 15, 'y': 582, 'width': 1183, 'height': 106}
# {'name': 'rect', 'x': 11, 'y': 825, 'width': 583, 'height': 106}
# {'name': 'rect', 'x': 11, 'y': 949, 'width': 207, 'height': 87}
# {'name': 'rect', 'x': 7, 'y': 8, 'width': 171, 'height': 30}
# {'name': 'rect', 'x': 262, 'y': 2, 'width': 114, 'height': 39}
# {'name': 'rect', 'x': 7, 'y': 46, 'width': 365, 'height': 19}
# {'name': 'rect', 'x': 31, 'y': 226, 'width': 316, 'height': 46}
# {'name': 'rect', 'x': 34, 'y': 77, 'width': 316, 'height': 46}
# {'name': 'rect', 'x': 34, 'y': 127, 'width': 316, 'height': 46}
# {'name': 'rect', 'x': 34, 'y': 176, 'width': 316, 'height': 46}
# {'name': 'rect', 'x': 41, 'y': 288, 'width': 299, 'height': 26}
# {'name': 'rect', 'x': 117, 'y': 334, 'width': 143, 'height': 63}
# {'name': 'rect', 'x': 49, 'y': 20, 'width': 325, 'height': 48}
# {'name': 'rect', 'x': 53, 'y': 72, 'width': 324, 'height': 50}
# {'name': 'rect', 'x': 164, 'y': 143, 'width': 23, 'height': 30}
# {'name': 'rect', 'x': 189, 'y': 147, 'width': 75, 'height': 25}
# {'name': 'rect', 'x': 151, 'y': 193, 'width': 123, 'height': 44}
# {'name': 'rect', 'x': 14, 'y': 10, 'width': 162, 'height': 44}
# {'name': 'rect', 'x': 17, 'y': 282, 'width': 78, 'height': 22}
# {'name': 'rect', 'x': 17, 'y': 301, 'width': 310, 'height': 46}
# {'name': 'rect', 'x': 16, 'y': 58, 'width': 78, 'height': 22}
# {'name': 'rect', 'x': 16, 'y': 77, 'width': 310, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 133, 'width': 78, 'height': 22}
# {'name': 'rect', 'x': 20, 'y': 152, 'width': 310, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 206, 'width': 96, 'height': 22}
# {'name': 'rect', 'x': 20, 'y': 225, 'width': 310, 'height': 46}
# {'name': 'rect', 'x': 16, 'y': 351, 'width': 53, 'height': 94}
# {'name': 'rect', 'x': 71, 'y': 348, 'width': 254, 'height': 95}
# {'name': 'rect', 'x': 14, 'y': 450, 'width': 197, 'height': 60}
# {'name': 'rect', 'x': 101, 'y': 29, 'width': 430, 'height': 50}
# {'name': 'rect', 'x': 82, 'y': 91, 'width': 474, 'height': 38}
# {'name': 'rect', 'x': 15, 'y': 354, 'width': 596, 'height': 88}
# {'name': 'rect', 'x': 17, 'y': 167, 'width': 290, 'height': 88}
# {'name': 'rect', 'x': 315, 'y': 167, 'width': 290, 'height': 88}
# {'name': 'rect', 'x': 14, 'y': 261, 'width': 596, 'height': 88}
# {'name': 'rect', 'x': 21, 'y': 444, 'width': 34, 'height': 39}
# {'name': 'rect', 'x': 57, 'y': 446, 'width': 490, 'height': 37}
# {'name': 'rect', 'x': 247, 'y': 514, 'width': 136, 'height': 69}
# {'name': 'rect', 'x': 18, 'y': 17, 'width': 90, 'height': 34}
# {'name': 'rect', 'x': 21, 'y': 54, 'width': 404, 'height': 12}
# {'name': 'rect', 'x': 17, 'y': 333, 'width': 98, 'height': 25}
# {'name': 'rect', 'x': 16, 'y': 362, 'width': 408, 'height': 53}
# {'name': 'rect', 'x': 19, 'y': 75, 'width': 85, 'height': 25}
# {'name': 'rect', 'x': 18, 'y': 104, 'width': 408, 'height': 53}
# {'name': 'rect', 'x': 19, 'y': 161, 'width': 98, 'height': 25}
# {'name': 'rect', 'x': 18, 'y': 190, 'width': 408, 'height': 53}
# {'name': 'rect', 'x': 18, 'y': 246, 'width': 98, 'height': 25}
# {'name': 'rect', 'x': 17, 'y': 275, 'width': 408, 'height': 53}
# {'name': 'rect', 'x': 14, 'y': 429, 'width': 363, 'height': 50}
# {'name': 'rect', 'x': 41, 'y': 493, 'width': 363, 'height': 143}
# {'name': 'rect', 'x': 31, 'y': 673, 'width': 23, 'height': 32}
# {'name': 'rect', 'x': 31, 'y': 712, 'width': 24, 'height': 31}
# {'name': 'rect', 'x': 59, 'y': 675, 'width': 192, 'height': 31}
# {'name': 'rect', 'x': 59, 'y': 710, 'width': 335, 'height': 46}
# {'name': 'rect', 'x': 19, 'y': 780, 'width': 408, 'height': 49}
# {'name': 'rect', 'x': 152, 'y': 8, 'width': 87, 'height': 40}
# {'name': 'rect', 'x': 39, 'y': 203, 'width': 310, 'height': 53}
# {'name': 'rect', 'x': 41, 'y': 68, 'width': 310, 'height': 53}
# {'name': 'rect', 'x': 41, 'y': 133, 'width': 310, 'height': 53}
# {'name': 'rect', 'x': 75, 'y': 264, 'width': 162, 'height': 32}
# {'name': 'rect', 'x': 252, 'y': 264, 'width': 62, 'height': 28}
# {'name': 'rect', 'x': 37, 'y': 335, 'width': 316, 'height': 43}
# {'name': 'rect', 'x': 70, 'y': 396, 'width': 257, 'height': 37}
# {'name': 'rect', 'x': 93, 'y': 507, 'width': 209, 'height': 56}
# {'name': 'rect', 'x': 92, 'y': 450, 'width': 209, 'height': 56}
# {'name': 'rect', 'x': 42, 'y': 19, 'width': 392, 'height': 38}
# {'name': 'rect', 'x': 133, 'y': 66, 'width': 197, 'height': 30}
# {'name': 'rect', 'x': 31, 'y': 181, 'width': 408, 'height': 67}
# {'name': 'rect', 'x': 31, 'y': 111, 'width': 408, 'height': 67}
# {'name': 'rect', 'x': 117, 'y': 259, 'width': 236, 'height': 25}
# {'name': 'rect', 'x': 360, 'y': 261, 'width': 76, 'height': 17}
# {'name': 'rect', 'x': 30, 'y': 259, 'width': 81, 'height': 23}
# {'name': 'rect', 'x': 32, 'y': 388, 'width': 104, 'height': 27}
# {'name': 'rect', 'x': 33, 'y': 417, 'width': 397, 'height': 46}
# {'name': 'rect', 'x': 31, 'y': 111, 'width': 408, 'height': 67}
# {'name': 'rect', 'x': 32, 'y': 310, 'width': 104, 'height': 27}
# {'name': 'rect', 'x': 33, 'y': 339, 'width': 397, 'height': 46}
# {'name': 'rect', 'x': 38, 'y': 466, 'width': 398, 'height': 61}
# {'name': 'rect', 'x': 111, 'y': 543, 'width': 247, 'height': 28}
# {'name': 'rect', 'x': 38, 'y': 589, 'width': 399, 'height': 63}
# {'name': 'rect', 'x': 9, 'y': 13, 'width': 345, 'height': 31}
# {'name': 'rect', 'x': 7, 'y': 66, 'width': 157, 'height': 31}
# {'name': 'rect', 'x': 3, 'y': 430, 'width': 220, 'height': 57}
# {'name': 'rect', 'x': 6, 'y': 120, 'width': 381, 'height': 57}
# {'name': 'rect', 'x': 8, 'y': 198, 'width': 381, 'height': 57}
# {'name': 'rect', 'x': 6, 'y': 280, 'width': 381, 'height': 57}
# {'name': 'rect', 'x': 7, 'y': 348, 'width': 24, 'height': 34}
# {'name': 'rect', 'x': 7, 'y': 392, 'width': 25, 'height': 28}
# {'name': 'rect', 'x': 36, 'y': 353, 'width': 206, 'height': 30}
# {'name': 'rect', 'x': 31, 'y': 392, 'width': 334, 'height': 30}
# {'name': 'rect', 'x': 4, 'y': 5, 'width': 227, 'height': 46}
# {'name': 'rect', 'x': 9, 'y': 45, 'width': 336, 'height': 23}
# {'name': 'rect', 'x': 7, 'y': 81, 'width': 188, 'height': 20}
# {'name': 'rect', 'x': 9, 'y': 265, 'width': 82, 'height': 16}
# {'name': 'rect', 'x': 9, 'y': 278, 'width': 293, 'height': 33}
# {'name': 'rect', 'x': 148, 'y': 109, 'width': 38, 'height': 16}
# {'name': 'rect', 'x': 146, 'y': 124, 'width': 141, 'height': 33}
# {'name': 'rect', 'x': 7, 'y': 212, 'width': 72, 'height': 16}
# {'name': 'rect', 'x': 5, 'y': 227, 'width': 293, 'height': 33}
# {'name': 'rect', 'x': 9, 'y': 160, 'width': 38, 'height': 16}
# {'name': 'rect', 'x': 7, 'y': 175, 'width': 293, 'height': 33}
# {'name': 'rect', 'x': 10, 'y': 109, 'width': 38, 'height': 16}
# {'name': 'rect', 'x': 8, 'y': 124, 'width': 141, 'height': 33}
# {'name': 'rect', 'x': 343, 'y': 1, 'width': 228, 'height': 85}
# {'name': 'rect', 'x': 4, 'y': 621, 'width': 968, 'height': 176}
# {'name': 'rect', 'x': 15, 'y': 104, 'width': 957, 'height': 148}
# {'name': 'rect', 'x': 10, 'y': 257, 'width': 957, 'height': 148}
# {'name': 'rect', 'x': 7, 'y': 409, 'width': 957, 'height': 148}
# Image Count: 157
# Class Count: 8
#   0. BG
#   1. input
#   2. button
#   3. text
#   4. select
#   5. checkbox
#   6. radiobutton
#   7. image

# %% [markdown]
# ## Display Samples
#
# Load and display images and masks.

# %%
# Load and display random samples
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Bounding Boxes
#
# Rather than using bounding box coordinates provided by the source datasets, we compute the bounding boxes from masks instead. This allows us to handle bounding boxes consistently regardless of the source dataset, and it also makes it easier to resize, rotate, or crop images because we simply generate the bounding boxes from the updates masks rather than computing bounding box transformation for each type of image transformation.

# %%
# Load random image and mask.
image_id = random.choice(dataset.image_ids)
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id  31 /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/datasets/form_login_ilya/train_filtered/train/2002.png
# image                    shape: (574, 422, 3)         min:   17.00000  max:  255.00000  uint8
# mask                     shape: (574, 422, 13)        min:    0.00000  max:    1.00000  bool
# class_ids                shape: (13,)                 min:    1.00000  max:    7.00000  int32
# bbox                     shape: (13, 4)               min:   10.00000  max:  570.00000  int32

# %% [markdown]
# ## Resize Images
#
# To support multiple images per batch, images are resized to one size (1024x1024). Aspect ratio is preserved, though. If an image is not square, then zero padding is added at the top/bottom or right/left.

# %%
# Load random image and mask.
image_id = np.random.choice(dataset.image_ids, 1)[0]
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
original_shape = image.shape
# Resize
image, window, scale, padding, _ = utils.resize_image(
    image, 
    min_dim=config.IMAGE_MIN_DIM, 
    max_dim=config.IMAGE_MAX_DIM,
    mode=config.IMAGE_RESIZE_MODE)
mask = utils.resize_mask(mask, scale, padding)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id: ", image_id, dataset.image_reference(image_id))
print("Original shape: ", original_shape)
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id:  147 /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/datasets/form_login_ilya/train_filtered/train/mockflow.png
# Original shape:  (398, 380, 3)
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# mask                     shape: (1024, 1024, 9)       min:    0.00000  max:    1.00000  bool
# class_ids                shape: (9,)                  min:    1.00000  max:    7.00000  int32
# bbox                     shape: (9, 4)                min:   97.00000  max:  929.00000  int32

# %% [markdown]
# ## Mini Masks
#
# Instance binary masks can get large when training with high resolution images. For example, if training with 1024x1024 image then the mask of a single instance requires 1MB of memory (Numpy uses bytes for boolean values). If an image has 100 instances then that's 100MB for the masks alone.
#
# To improve training speed, we optimize masks by:
# * We store mask pixels that are inside the object bounding box, rather than a mask of the full image. Most objects are small compared to the image size, so we save space by not storing a lot of zeros around the object.
# * We resize the mask to a smaller size (e.g. 56x56). For objects that are larger than the selected size we lose a bit of accuracy. But most object annotations are not very accuracy to begin with, so this loss is negligable for most practical purposes. Thie size of the mini_mask can be set in the config class.
#
# To visualize the effect of mask resizing, and to verify the code correctness, we visualize some examples.

# %%
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, use_mini_mask=False)

log("image", image)
log("image_meta", image_meta)
log("class_ids", class_ids)
log("bbox", bbox)
log("mask", mask)

display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (20,)                 min:    1.00000  max: 1024.00000  float64
# class_ids                shape: (5,)                  min:    1.00000  max:    2.00000  int32
# bbox                     shape: (5, 4)                min:  105.00000  max:  929.00000  int32
# mask                     shape: (1024, 1024, 5)       min:    0.00000  max:    1.00000  bool

# %%
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %%
# Add augmentation and mask resizing.
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, augment=True, use_mini_mask=True)
log("mask", mask)
display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# WARNING:root:'augment' is deprecated. Use 'augmentation' instead.
# mask                     shape: (56, 56, 5)           min:    1.00000  max:    1.00000  bool

# %%
mask = utils.expand_mask(bbox, mask, image.shape)
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Anchors
#
# The order of anchors is important. Use the same order in training and prediction phases. And it must match the order of the convolution execution.
#
# For an FPN network, the anchors must be ordered in a way that makes it easy to match anchors to the output of the convolution layers that predict anchor scores and shifts.
# * Sort by pyramid level first. All anchors of the first level, then all of the second and so on. This makes it easier to separate anchors by level.
# * Within each level, sort anchors by feature map processing sequence. Typically, a convolution layer processes a feature map starting from top-left and moving right row by row.
# * For each feature map cell, pick any sorting order for the anchors of different ratios. Here we match the order of ratios passed to the function.
#
# **Anchor Stride:**
# In the FPN architecture, feature maps at the first few layers are high resolution. For example, if the input image is 1024x1024 then the feature meap of the first layer is 256x256, which generates about 200K anchors (256*256*3). These anchors are 32x32 pixels and their stride relative to image pixels is 4 pixels, so there is a lot of overlap. We can reduce the load significantly if we generate anchors for every other cell in the feature map. A stride of 2 will cut the number of anchors by 4, for example.
#
# In this implementation we use an anchor stride of 2, which is different from the paper.

# %%
# Generate Anchors
backbone_shapes = modellib.compute_backbone_shapes(config, config.IMAGE_SHAPE)
anchors = utils.generate_pyramid_anchors(config.RPN_ANCHOR_SCALES, 
                                          config.RPN_ANCHOR_RATIOS,
                                          backbone_shapes,
                                          config.BACKBONE_STRIDES, 
                                          config.RPN_ANCHOR_STRIDE)

# Print summary of anchors
num_levels = len(backbone_shapes)
anchors_per_cell = len(config.RPN_ANCHOR_RATIOS)
print("Count: ", anchors.shape[0])
print("Scales: ", config.RPN_ANCHOR_SCALES)
print("ratios: ", config.RPN_ANCHOR_RATIOS)
print("Anchors per Cell: ", anchors_per_cell)
print("Levels: ", num_levels)
anchors_per_level = []
for l in range(num_levels):
    num_cells = backbone_shapes[l][0] * backbone_shapes[l][1]
    anchors_per_level.append(anchors_per_cell * num_cells // config.RPN_ANCHOR_STRIDE**2)
    print("Anchors in Level {}: {}".format(l, anchors_per_level[l]))
# Out:
# Count:  261888
# Scales:  (32, 64, 128, 256, 512)
# ratios:  [0.5, 1, 2]
# Anchors per Cell:  3
# Levels:  5
# Anchors in Level 0: 196608
# Anchors in Level 1: 49152
# Anchors in Level 2: 12288
# Anchors in Level 3: 3072
# Anchors in Level 4: 768

# %% [markdown]
# Visualize anchors of one cell at the center of the feature map of a specific level.

# %%
## Visualize anchors of one cell at the center of the feature map of a specific level

# Load and draw random image
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, _, _, _ = modellib.load_image_gt(dataset, config, image_id)
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.imshow(image)
levels = len(backbone_shapes)

for level in range(levels):
    colors = visualize.random_colors(levels)
    # Compute the index of the anchors at the center of the image
    level_start = sum(anchors_per_level[:level]) # sum of anchors of previous levels
    level_anchors = anchors[level_start:level_start+anchors_per_level[level]]
    print("Level {}. Anchors: {:6}  Feature map Shape: {}".format(level, level_anchors.shape[0], 
                                                                  backbone_shapes[level]))
    center_cell = backbone_shapes[level] // 2
    center_cell_index = (center_cell[0] * backbone_shapes[level][1] + center_cell[1])
    level_center = center_cell_index * anchors_per_cell 
    center_anchor = anchors_per_cell * (
        (center_cell[0] * backbone_shapes[level][1] / config.RPN_ANCHOR_STRIDE**2) \
        + center_cell[1] / config.RPN_ANCHOR_STRIDE)
    level_center = int(center_anchor)

    # Draw anchors. Brightness show the order in the array, dark to bright.
    for i, rect in enumerate(level_anchors[level_center:level_center+anchors_per_cell]):
        y1, x1, y2, x2 = rect
        p = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, facecolor='none',
                              edgecolor=(i+1)*np.array(colors[level]) / anchors_per_cell)
        ax.add_patch(p)
# Out:
# Level 0. Anchors: 196608  Feature map Shape: [256 256]
# Level 1. Anchors:  49152  Feature map Shape: [128 128]
# Level 2. Anchors:  12288  Feature map Shape: [64 64]
# Level 3. Anchors:   3072  Feature map Shape: [32 32]
# Level 4. Anchors:    768  Feature map Shape: [16 16]

# %% [markdown]
# ## Data Generator

# %%
# Create data generator
random_rois = 2000
g = modellib.data_generator(
    dataset, config, shuffle=True, random_rois=random_rois, 
    batch_size=4,
    detection_targets=True)

# %%
# Uncomment to run the generator through a lot of images
# to catch rare errors
# for i in range(1000):
#     print(i)
#     _, _ = next(g)

# %%
# Get Next Image
if random_rois:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_class_ids, gt_boxes, gt_masks, rpn_rois, rois], \
    [mrcnn_class_ids, mrcnn_bbox, mrcnn_mask] = next(g)
    
    log("rois", rois)
    log("mrcnn_class_ids", mrcnn_class_ids)
    log("mrcnn_bbox", mrcnn_bbox)
    log("mrcnn_mask", mrcnn_mask)
else:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_boxes, gt_masks], _ = next(g)
    
log("gt_class_ids", gt_class_ids)
log("gt_boxes", gt_boxes)
log("gt_masks", gt_masks)
log("rpn_match", rpn_match, )
log("rpn_bbox", rpn_bbox)
image_id = modellib.parse_image_meta(image_meta)["image_id"][0]
print("image_id: ", image_id, dataset.image_reference(image_id))

# Remove the last dim in mrcnn_class_ids. It's only added
# to satisfy Keras restriction on target shape.
mrcnn_class_ids = mrcnn_class_ids[:,:,0]
# Out:
# rois                     shape: (4, 200, 4)           min:    0.00000  max: 1023.00000  int32
# mrcnn_class_ids          shape: (4, 200, 1)           min:    0.00000  max:    7.00000  int32
# mrcnn_bbox               shape: (4, 200, 8, 4)        min:   -3.60440  max:    3.58696  float32
# mrcnn_mask               shape: (4, 200, 28, 28, 8)   min:    0.00000  max:    1.00000  float32
# gt_class_ids             shape: (4, 100)              min:    0.00000  max:    7.00000  int32
# gt_boxes                 shape: (4, 100, 4)           min:    0.00000  max: 1018.00000  int32
# gt_masks                 shape: (4, 56, 56, 100)      min:    0.00000  max:    1.00000  bool
# rpn_match                shape: (4, 261888, 1)        min:   -1.00000  max:    1.00000  int32
# rpn_bbox                 shape: (4, 256, 4)           min:  -12.54010  max:    9.80558  float64
# image_id:  77 /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/datasets/form_login_ilya/train_filtered/train/bookit.png

# %%
b = 0

# Restore original image (reverse normalization)
sample_image = modellib.unmold_image(normalized_images[b], config)

# Compute anchor shifts.
indices = np.where(rpn_match[b] == 1)[0]
refined_anchors = utils.apply_box_deltas(anchors[indices], rpn_bbox[b, :len(indices)] * config.RPN_BBOX_STD_DEV)
log("anchors", anchors)
log("refined_anchors", refined_anchors)

# Get list of positive anchors
positive_anchor_ids = np.where(rpn_match[b] == 1)[0]
print("Positive anchors: {}".format(len(positive_anchor_ids)))
negative_anchor_ids = np.where(rpn_match[b] == -1)[0]
print("Negative anchors: {}".format(len(negative_anchor_ids)))
neutral_anchor_ids = np.where(rpn_match[b] == 0)[0]
print("Neutral anchors: {}".format(len(neutral_anchor_ids)))

# ROI breakdown by class
for c, n in zip(dataset.class_names, np.bincount(mrcnn_class_ids[b].flatten())):
    if n:
        print("{:23}: {}".format(c[:20], n))

# Show positive anchors
fig, ax = plt.subplots(1, figsize=(16, 16))
visualize.draw_boxes(sample_image, boxes=anchors[positive_anchor_ids], 
                     refined_boxes=refined_anchors, ax=ax)
# Out:
# anchors                  shape: (261888, 4)           min: -362.03867  max: 1322.03867  float64
# refined_anchors          shape: (128, 4)              min:   35.00000  max: 1018.00000  float32
# Positive anchors: 128
# Negative anchors: 128
# Neutral anchors: 261632
# BG                     : 155
# input                  : 30
# button                 : 6
# text                   : 9

# %%
# Show negative anchors
visualize.draw_boxes(sample_image, boxes=anchors[negative_anchor_ids])

# %%
# Show neutral anchors. They don't contribute to training.
visualize.draw_boxes(sample_image, boxes=anchors[np.random.choice(neutral_anchor_ids, 100)])

# %% [markdown]
# ## ROIs

# %%
if random_rois:
    # Class aware bboxes
    bbox_specific = mrcnn_bbox[b, np.arange(mrcnn_bbox.shape[1]), mrcnn_class_ids[b], :]

    # Refined ROIs
    refined_rois = utils.apply_box_deltas(rois[b].astype(np.float32), bbox_specific[:,:4] * config.BBOX_STD_DEV)

    # Class aware masks
    mask_specific = mrcnn_mask[b, np.arange(mrcnn_mask.shape[1]), :, :, mrcnn_class_ids[b]]

    visualize.draw_rois(sample_image, rois[b], refined_rois, mask_specific, mrcnn_class_ids[b], dataset.class_names)
    
    # Any repeated ROIs?
    rows = np.ascontiguousarray(rois[b]).view(np.dtype((np.void, rois.dtype.itemsize * rois.shape[-1])))
    _, idx = np.unique(rows, return_index=True)
    print("Unique ROIs: {} out of {}".format(len(idx), rois.shape[1]))
# Out:
# Positive ROIs:  45
# Negative ROIs:  155
# Positive Ratio: 0.23
# Unique ROIs: 200 out of 200

# %%
if random_rois:
    # Dispalay ROIs and corresponding masks and bounding boxes
    ids = random.sample(range(rois.shape[1]), 8)

    images = []
    titles = []
    for i in ids:
        image = visualize.draw_box(sample_image.copy(), rois[b,i,:4].astype(np.int32), [255, 0, 0])
        image = visualize.draw_box(image, refined_rois[i].astype(np.int64), [0, 255, 0])
        images.append(image)
        titles.append("ROI {}".format(i))
        images.append(mask_specific[i] * 255)
        titles.append(dataset.class_names[mrcnn_class_ids[b,i]][:20])

    display_images(images, titles, cols=4, cmap="Blues", interpolation="none")

# %%
# Check ratio of positive ROIs in a set of images.
if random_rois:
    limit = 10
    temp_g = modellib.data_generator(
        dataset, config, shuffle=True, random_rois=10000, 
        batch_size=1, detection_targets=True)
    total = 0
    for i in range(limit):
        _, [ids, _, _] = next(temp_g)
        positive_rois = np.sum(ids[0] > 0)
        total += positive_rois
        print("{:5} {:5.2f}".format(positive_rois, positive_rois/ids.shape[1]))
    print("Average percent: {:.2f}".format(total/(limit*ids.shape[1])))
# Out:
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
# Average percent: 0.33
