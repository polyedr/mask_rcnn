# %% [markdown]
# # Mask R-CNN - Inspect Form Login Trained Model
#
# Code and visualizations to test, debug, and evaluate the Mask R-CNN model.

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.form_login import form_login

# %matplotlib inline 

# Directory to save logs and trained model
#MODEL_DIR = os.path.join(ROOT_DIR, "logs")
MODEL_DIR = os.path.join("logs")
# Path to Ballon trained weights
# You can download this file from the Releases page
# https://github.com/matterport/Mask_RCNN/releases
#BALLON_WEIGHTS_PATH = "/path/to/mask_rcnn_form_login.h5"  # TODO: update this path
# About 70% efficiency model
BALLON_WEIGHTS_PATH = "/home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/mask_rcnn_form_login_0026.h5"
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
config = form_login.Form_loginConfig()
BALLOON_DIR = os.path.join(ROOT_DIR, "datasets/form_login_ilya/train_filtered")

# %%
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                20
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           form_login
# NUM_CLASSES                    8
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                40
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
# Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

# %%
def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Load Validation Dataset

# %%
# Load validation dataset
dataset = form_login.Form_loginDataset()
dataset.load_form_login(BALLOON_DIR, "val")

# Must call before using the dataset
dataset.prepare()

print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# {'name': 'rect', 'x': 6, 'y': 7, 'width': 109, 'height': 26}
# {'name': 'rect', 'x': 9, 'y': 40, 'width': 157, 'height': 26}
# {'name': 'rect', 'x': 5, 'y': 87, 'width': 212, 'height': 28}
# {'name': 'rect', 'x': 4, 'y': 107, 'width': 333, 'height': 65}
# {'name': 'rect', 'x': 9, 'y': 189, 'width': 78, 'height': 25}
# {'name': 'rect', 'x': 10, 'y': 207, 'width': 327, 'height': 62}
# {'name': 'rect', 'x': 222, 'y': 263, 'width': 116, 'height': 43}
# {'name': 'rect', 'x': 5, 'y': 291, 'width': 162, 'height': 72}
# {'name': 'rect', 'x': 6, 'y': 378, 'width': 150, 'height': 28}
# {'name': 'rect', 'x': 4, 'y': 415, 'width': 152, 'height': 32}
# {'name': 'rect', 'x': 127, 'y': 4, 'width': 205, 'height': 47}
# {'name': 'rect', 'x': 133, 'y': 53, 'width': 211, 'height': 30}
# {'name': 'rect', 'x': 93, 'y': 181, 'width': 362, 'height': 103}
# {'name': 'rect', 'x': 94, 'y': 291, 'width': 359, 'height': 88}
# {'name': 'rect', 'x': 89, 'y': 387, 'width': 371, 'height': 88}
# {'name': 'rect', 'x': 92, 'y': 485, 'width': 362, 'height': 90}
# {'name': 'rect', 'x': 93, 'y': 585, 'width': 363, 'height': 87}
# {'name': 'rect', 'x': 12, 'y': 178, 'width': 81, 'height': 103}
# {'name': 'rect', 'x': 17, 'y': 287, 'width': 78, 'height': 87}
# {'name': 'rect', 'x': 20, 'y': 386, 'width': 69, 'height': 93}
# {'name': 'rect', 'x': 18, 'y': 490, 'width': 75, 'height': 88}
# {'name': 'rect', 'x': 16, 'y': 584, 'width': 77, 'height': 91}
# {'name': 'rect', 'x': 34, 'y': 695, 'width': 396, 'height': 49}
# {'name': 'rect', 'x': 3, 'y': 830, 'width': 472, 'height': 101}
# {'name': 'rect', 'x': 105, 'y': 102, 'width': 205, 'height': 47}
# {'name': 'rect', 'x': 102, 'y': 46, 'width': 211, 'height': 30}
# {'name': 'rect', 'x': 103, 'y': 149, 'width': 211, 'height': 30}
# {'name': 'rect', 'x': 104, 'y': 4, 'width': 205, 'height': 47}
# {'name': 'rect', 'x': 73, 'y': 288, 'width': 358, 'height': 86}
# {'name': 'rect', 'x': 74, 'y': 387, 'width': 359, 'height': 86}
# {'name': 'rect', 'x': 4, 'y': 283, 'width': 71, 'height': 90}
# {'name': 'rect', 'x': 3, 'y': 387, 'width': 72, 'height': 84}
# {'name': 'rect', 'x': 18, 'y': 480, 'width': 178, 'height': 33}
# {'name': 'rect', 'x': 227, 'y': 481, 'width': 34, 'height': 32}
# {'name': 'rect', 'x': 262, 'y': 478, 'width': 159, 'height': 31}
# {'name': 'rect', 'x': 6, 'y': 539, 'width': 424, 'height': 93}
# {'name': 'rect', 'x': 3, 'y': 2, 'width': 426, 'height': 74}
# {'name': 'rect', 'x': 2, 'y': 93, 'width': 425, 'height': 77}
# {'name': 'rect', 'x': 1, 'y': 185, 'width': 427, 'height': 75}
# {'name': 'rect', 'x': 32, 'y': 280, 'width': 37, 'height': 41}
# {'name': 'rect', 'x': 74, 'y': 280, 'width': 325, 'height': 39}
# {'name': 'rect', 'x': 102, 'y': 327, 'width': 227, 'height': 71}
# {'name': 'rect', 'x': 7, 'y': 1, 'width': 395, 'height': 34}
# {'name': 'rect', 'x': 2, 'y': 40, 'width': 472, 'height': 75}
# {'name': 'rect', 'x': 3, 'y': 122, 'width': 469, 'height': 68}
# {'name': 'rect', 'x': 4, 'y': 197, 'width': 469, 'height': 76}
# {'name': 'rect', 'x': 270, 'y': 272, 'width': 204, 'height': 64}
# {'name': 'rect', 'x': 92, 'y': 4, 'width': 137, 'height': 37}
# {'name': 'rect', 'x': 3, 'y': 61, 'width': 57, 'height': 27}
# {'name': 'rect', 'x': 3, 'y': 142, 'width': 84, 'height': 27}
# {'name': 'rect', 'x': 3, 'y': 87, 'width': 305, 'height': 50}
# {'name': 'rect', 'x': 8, 'y': 171, 'width': 304, 'height': 44}
# {'name': 'rect', 'x': 1, 'y': 234, 'width': 310, 'height': 53}
# {'name': 'rect', 'x': 49, 'y': 3, 'width': 83, 'height': 28}
# {'name': 'rect', 'x': 45, 'y': 32, 'width': 216, 'height': 18}
# {'name': 'rect', 'x': 23, 'y': 49, 'width': 411, 'height': 18}
# {'name': 'rect', 'x': 64, 'y': 76, 'width': 88, 'height': 27}
# {'name': 'rect', 'x': 68, 'y': 115, 'width': 84, 'height': 21}
# {'name': 'rect', 'x': 65, 'y': 149, 'width': 85, 'height': 23}
# {'name': 'rect', 'x': 33, 'y': 186, 'width': 118, 'height': 22}
# {'name': 'rect', 'x': 40, 'y': 217, 'width': 112, 'height': 30}
# {'name': 'rect', 'x': 108, 'y': 256, 'width': 42, 'height': 24}
# {'name': 'rect', 'x': 82, 'y': 286, 'width': 68, 'height': 29}
# {'name': 'rect', 'x': 146, 'y': 331, 'width': 129, 'height': 44}
# {'name': 'rect', 'x': 144, 'y': 318, 'width': 177, 'height': 21}
# {'name': 'rect', 'x': 294, 'y': 285, 'width': 80, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 70, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 70, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 111, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 142, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 180, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 215, 'width': 282, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 252, 'width': 110, 'height': 39}
# {'name': 'rect', 'x': 149, 'y': 285, 'width': 80, 'height': 39}
# {'name': 'rect', 'x': 216, 'y': 285, 'width': 80, 'height': 39}
# {'name': 'rect', 'x': 4, 'y': 1, 'width': 284, 'height': 25}
# {'name': 'rect', 'x': 9, 'y': 33, 'width': 72, 'height': 18}
# {'name': 'rect', 'x': 8, 'y': 100, 'width': 110, 'height': 19}
# {'name': 'rect', 'x': 7, 'y': 162, 'width': 79, 'height': 24}
# {'name': 'rect', 'x': 7, 'y': 50, 'width': 280, 'height': 42}
# {'name': 'rect', 'x': 9, 'y': 111, 'width': 273, 'height': 52}
# {'name': 'rect', 'x': 11, 'y': 178, 'width': 276, 'height': 47}
# {'name': 'rect', 'x': 13, 'y': 225, 'width': 90, 'height': 31}
# {'name': 'rect', 'x': 4, 'y': 3, 'width': 309, 'height': 30}
# {'name': 'rect', 'x': 3, 'y': 43, 'width': 51, 'height': 26}
# {'name': 'rect', 'x': 4, 'y': 65, 'width': 306, 'height': 54}
# {'name': 'rect', 'x': 3, 'y': 127, 'width': 63, 'height': 29}
# {'name': 'rect', 'x': 5, 'y': 154, 'width': 305, 'height': 48}
# {'name': 'rect', 'x': 4, 'y': 214, 'width': 74, 'height': 20}
# {'name': 'rect', 'x': 4, 'y': 236, 'width': 309, 'height': 52}
# {'name': 'rect', 'x': 3, 'y': 293, 'width': 204, 'height': 51}
# {'name': 'rect', 'x': 202, 'y': 5, 'width': 101, 'height': 24}
# {'name': 'rect', 'x': 1, 'y': 5, 'width': 192, 'height': 21}
# {'name': 'rect', 'x': 309, 'y': 5, 'width': 194, 'height': 20}
# {'name': 'rect', 'x': 4, 'y': 57, 'width': 92, 'height': 27}
# {'name': 'rect', 'x': 6, 'y': 162, 'width': 126, 'height': 24}
# {'name': 'rect', 'x': 4, 'y': 267, 'width': 119, 'height': 24}
# {'name': 'rect', 'x': 8, 'y': 371, 'width': 47, 'height': 33}
# {'name': 'rect', 'x': 6, 'y': 481, 'width': 82, 'height': 27}
# {'name': 'rect', 'x': 258, 'y': 89, 'width': 247, 'height': 65}
# {'name': 'rect', 'x': 7, 'y': 89, 'width': 247, 'height': 65}
# {'name': 'rect', 'x': 1, 'y': 192, 'width': 503, 'height': 62}
# {'name': 'rect', 'x': 3, 'y': 297, 'width': 502, 'height': 62}
# {'name': 'rect', 'x': 8, 'y': 399, 'width': 497, 'height': 64}
# {'name': 'rect', 'x': 4, 'y': 507, 'width': 502, 'height': 63}
# {'name': 'rect', 'x': 146, 'y': 6, 'width': 124, 'height': 28}
# {'name': 'rect', 'x': 0, 'y': 124, 'width': 410, 'height': 46}
# {'name': 'rect', 'x': 0, 'y': 39, 'width': 410, 'height': 28}
# {'name': 'rect', 'x': 0, 'y': 39, 'width': 410, 'height': 28}
# {'name': 'rect', 'x': 0, 'y': 67, 'width': 410, 'height': 28}
# {'name': 'rect', 'x': 0, 'y': 94, 'width': 410, 'height': 28}
# {'name': 'rect', 'x': 1, 'y': 4, 'width': 50, 'height': 30}
# {'name': 'rect', 'x': 58, 'y': 3, 'width': 48, 'height': 28}
# {'name': 'rect', 'x': 114, 'y': 4, 'width': 92, 'height': 27}
# {'name': 'rect', 'x': 213, 'y': 3, 'width': 91, 'height': 28}
# {'name': 'rect', 'x': 16, 'y': 44, 'width': 379, 'height': 49}
# {'name': 'rect', 'x': 14, 'y': 93, 'width': 382, 'height': 57}
# {'name': 'rect', 'x': 19, 'y': 153, 'width': 27, 'height': 34}
# {'name': 'rect', 'x': 48, 'y': 163, 'width': 96, 'height': 23}
# {'name': 'rect', 'x': 153, 'y': 202, 'width': 109, 'height': 40}
# {'name': 'rect', 'x': 3, 'y': 2, 'width': 69, 'height': 20}
# {'name': 'rect', 'x': 5, 'y': 25, 'width': 223, 'height': 12}
# {'name': 'rect', 'x': 1, 'y': 262, 'width': 231, 'height': 41}
# {'name': 'rect', 'x': 1, 'y': 46, 'width': 231, 'height': 41}
# {'name': 'rect', 'x': 0, 'y': 92, 'width': 231, 'height': 41}
# {'name': 'rect', 'x': 1, 'y': 140, 'width': 231, 'height': 41}
# {'name': 'rect', 'x': 32, 'y': 228, 'width': 127, 'height': 22}
# {'name': 'rect', 'x': 4, 'y': 227, 'width': 25, 'height': 23}
# {'name': 'rect', 'x': 31, 'y': 191, 'width': 127, 'height': 22}
# {'name': 'rect', 'x': 3, 'y': 190, 'width': 25, 'height': 23}
# {'name': 'rect', 'x': 7, 'y': 3, 'width': 72, 'height': 26}
# {'name': 'rect', 'x': 8, 'y': 35, 'width': 249, 'height': 21}
# {'name': 'rect', 'x': 20, 'y': 250, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 2, 'y': 249, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 272, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 21, 'y': 117, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 3, 'y': 116, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 3, 'y': 139, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 20, 'y': 183, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 2, 'y': 182, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 205, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 2, 'y': 334, 'width': 399, 'height': 37}
# {'name': 'rect', 'x': 7, 'y': 3, 'width': 72, 'height': 26}
# {'name': 'rect', 'x': 7, 'y': 31, 'width': 249, 'height': 21}
# {'name': 'rect', 'x': 22, 'y': 314, 'width': 121, 'height': 22}
# {'name': 'rect', 'x': 4, 'y': 313, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 4, 'y': 336, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 21, 'y': 117, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 3, 'y': 116, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 3, 'y': 139, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 20, 'y': 183, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 2, 'y': 182, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 205, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 3, 'y': 396, 'width': 399, 'height': 37}
# {'name': 'rect', 'x': 20, 'y': 250, 'width': 55, 'height': 22}
# {'name': 'rect', 'x': 2, 'y': 249, 'width': 18, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 272, 'width': 396, 'height': 37}
# {'name': 'rect', 'x': 1, 'y': 1, 'width': 375, 'height': 49}
# {'name': 'rect', 'x': 2, 'y': 113, 'width': 121, 'height': 31}
# {'name': 'rect', 'x': 308, 'y': 261, 'width': 225, 'height': 61}
# {'name': 'rect', 'x': 4, 'y': 264, 'width': 225, 'height': 61}
# {'name': 'rect', 'x': 308, 'y': 150, 'width': 225, 'height': 61}
# {'name': 'rect', 'x': 4, 'y': 153, 'width': 225, 'height': 61}
# {'name': 'rect', 'x': 5, 'y': 379, 'width': 529, 'height': 67}
# {'name': 'rect', 'x': 4, 'y': 494, 'width': 328, 'height': 93}
# {'name': 'rect', 'x': 2, 'y': 0, 'width': 77, 'height': 23}
# {'name': 'rect', 'x': 2, 'y': 21, 'width': 402, 'height': 9}
# {'name': 'rect', 'x': 1, 'y': 38, 'width': 191, 'height': 24}
# {'name': 'rect', 'x': 219, 'y': 66, 'width': 186, 'height': 50}
# {'name': 'rect', 'x': 14, 'y': 66, 'width': 186, 'height': 50}
# {'name': 'rect', 'x': 14, 'y': 229, 'width': 388, 'height': 47}
# {'name': 'rect', 'x': 15, 'y': 120, 'width': 388, 'height': 47}
# {'name': 'rect', 'x': 15, 'y': 175, 'width': 388, 'height': 47}
# {'name': 'rect', 'x': 28, 'y': 296, 'width': 73, 'height': 30}
# {'name': 'rect', 'x': 10, 'y': 339, 'width': 22, 'height': 22}
# {'name': 'rect', 'x': 106, 'y': 340, 'width': 22, 'height': 22}
# {'name': 'rect', 'x': 36, 'y': 340, 'width': 45, 'height': 23}
# {'name': 'rect', 'x': 129, 'y': 338, 'width': 40, 'height': 22}
# {'name': 'rect', 'x': 16, 'y': 368, 'width': 94, 'height': 45}
# {'name': 'rect', 'x': 316, 'y': 290, 'width': 88, 'height': 38}
# {'name': 'rect', 'x': 115, 'y': 290, 'width': 88, 'height': 38}
# {'name': 'rect', 'x': 215, 'y': 290, 'width': 88, 'height': 38}
# {'name': 'rect', 'x': 37, 'y': 0, 'width': 101, 'height': 31}
# {'name': 'rect', 'x': 1, 'y': 157, 'width': 189, 'height': 48}
# {'name': 'rect', 'x': 3, 'y': 41, 'width': 189, 'height': 48}
# {'name': 'rect', 'x': 5, 'y': 94, 'width': 189, 'height': 48}
# {'name': 'rect', 'x': 3, 'y': 225, 'width': 123, 'height': 38}
# {'name': 'rect', 'x': 133, 'y': 221, 'width': 214, 'height': 46}
# {'name': 'rect', 'x': 3, 'y': 6, 'width': 110, 'height': 38}
# {'name': 'rect', 'x': 133, 'y': 2, 'width': 214, 'height': 46}
# {'name': 'rect', 'x': 3, 'y': 59, 'width': 110, 'height': 38}
# {'name': 'rect', 'x': 133, 'y': 55, 'width': 214, 'height': 46}
# {'name': 'rect', 'x': 4, 'y': 111, 'width': 110, 'height': 38}
# {'name': 'rect', 'x': 134, 'y': 107, 'width': 214, 'height': 46}
# {'name': 'rect', 'x': 5, 'y': 171, 'width': 110, 'height': 38}
# {'name': 'rect', 'x': 134, 'y': 280, 'width': 212, 'height': 42}
# {'name': 'rect', 'x': 6, 'y': 2, 'width': 45, 'height': 21}
# {'name': 'rect', 'x': 3, 'y': 69, 'width': 72, 'height': 22}
# {'name': 'rect', 'x': 3, 'y': 23, 'width': 288, 'height': 47}
# {'name': 'rect', 'x': 3, 'y': 88, 'width': 288, 'height': 47}
# {'name': 'rect', 'x': 182, 'y': 140, 'width': 106, 'height': 16}
# {'name': 'rect', 'x': 3, 'y': 162, 'width': 118, 'height': 34}
# {'name': 'rect', 'x': 162, 'y': 157, 'width': 128, 'height': 47}
# {'name': 'rect', 'x': 69, 'y': 329, 'width': 449, 'height': 54}
# {'name': 'rect', 'x': 4, 'y': 2, 'width': 571, 'height': 90}
# {'name': 'rect', 'x': 6, 'y': 109, 'width': 571, 'height': 90}
# {'name': 'rect', 'x': 9, 'y': 213, 'width': 571, 'height': 90}
# {'name': 'rect', 'x': 19, 'y': 324, 'width': 50, 'height': 63}
# {'name': 'rect', 'x': 6, 'y': 404, 'width': 575, 'height': 88}
# {'name': 'rect', 'x': 99, 'y': 0, 'width': 72, 'height': 27}
# {'name': 'rect', 'x': 7, 'y': 148, 'width': 62, 'height': 24}
# {'name': 'rect', 'x': 70, 'y': 148, 'width': 138, 'height': 28}
# {'name': 'rect', 'x': 21, 'y': 40, 'width': 50, 'height': 24}
# {'name': 'rect', 'x': 72, 'y': 40, 'width': 148, 'height': 28}
# {'name': 'rect', 'x': 20, 'y': 76, 'width': 50, 'height': 24}
# {'name': 'rect', 'x': 71, 'y': 76, 'width': 148, 'height': 28}
# {'name': 'rect', 'x': 19, 'y': 111, 'width': 50, 'height': 24}
# {'name': 'rect', 'x': 70, 'y': 111, 'width': 148, 'height': 28}
# {'name': 'rect', 'x': 209, 'y': 150, 'width': 62, 'height': 24}
# {'name': 'rect', 'x': 51, 'y': 2, 'width': 218, 'height': 28}
# {'name': 'rect', 'x': 22, 'y': 56, 'width': 270, 'height': 24}
# {'name': 'rect', 'x': 3, 'y': 267, 'width': 308, 'height': 59}
# {'name': 'rect', 'x': 3, 'y': 92, 'width': 308, 'height': 59}
# {'name': 'rect', 'x': 3, 'y': 153, 'width': 308, 'height': 59}
# {'name': 'rect', 'x': 3, 'y': 212, 'width': 308, 'height': 59}
# {'name': 'rect', 'x': 6, 'y': 135, 'width': 85, 'height': 30}
# {'name': 'rect', 'x': 93, 'y': 135, 'width': 238, 'height': 39}
# {'name': 'rect', 'x': 17, 'y': 2, 'width': 73, 'height': 30}
# {'name': 'rect', 'x': 93, 'y': 2, 'width': 238, 'height': 39}
# {'name': 'rect', 'x': 17, 'y': 46, 'width': 73, 'height': 30}
# {'name': 'rect', 'x': 93, 'y': 46, 'width': 238, 'height': 39}
# {'name': 'rect', 'x': 17, 'y': 179, 'width': 73, 'height': 30}
# {'name': 'rect', 'x': 94, 'y': 272, 'width': 238, 'height': 61}
# {'name': 'rect', 'x': 3, 'y': 93, 'width': 88, 'height': 30}
# {'name': 'rect', 'x': 93, 'y': 93, 'width': 238, 'height': 39}
# {'name': 'rect', 'x': 94, 'y': 179, 'width': 238, 'height': 90}
# {'name': 'rect', 'x': 4, 'y': 2, 'width': 390, 'height': 31}
# {'name': 'rect', 'x': 19, 'y': 265, 'width': 372, 'height': 61}
# {'name': 'rect', 'x': 21, 'y': 44, 'width': 372, 'height': 61}
# {'name': 'rect', 'x': 19, 'y': 118, 'width': 372, 'height': 61}
# {'name': 'rect', 'x': 20, 'y': 185, 'width': 372, 'height': 61}
# {'name': 'rect', 'x': 341, 'y': 247, 'width': 50, 'height': 11}
# {'name': 'rect', 'x': 7, 'y': 2, 'width': 62, 'height': 25}
# {'name': 'rect', 'x': 7, 'y': 245, 'width': 67, 'height': 14}
# {'name': 'rect', 'x': 5, 'y': 261, 'width': 278, 'height': 39}
# {'name': 'rect', 'x': 6, 'y': 60, 'width': 67, 'height': 14}
# {'name': 'rect', 'x': 4, 'y': 76, 'width': 278, 'height': 39}
# {'name': 'rect', 'x': 4, 'y': 154, 'width': 67, 'height': 14}
# {'name': 'rect', 'x': 2, 'y': 170, 'width': 278, 'height': 39}
# {'name': 'rect', 'x': 9, 'y': 334, 'width': 104, 'height': 43}
# {'name': 'rect', 'x': 4, 'y': 1, 'width': 187, 'height': 36}
# {'name': 'rect', 'x': 7, 'y': 279, 'width': 187, 'height': 51}
# {'name': 'rect', 'x': 5, 'y': 66, 'width': 187, 'height': 51}
# {'name': 'rect', 'x': 7, 'y': 119, 'width': 187, 'height': 51}
# {'name': 'rect', 'x': 7, 'y': 173, 'width': 187, 'height': 51}
# {'name': 'rect', 'x': 7, 'y': 4, 'width': 422, 'height': 34}
# {'name': 'rect', 'x': 7, 'y': 184, 'width': 420, 'height': 58}
# {'name': 'rect', 'x': 7, 'y': 64, 'width': 420, 'height': 58}
# {'name': 'rect', 'x': 7, 'y': 124, 'width': 420, 'height': 58}
# {'name': 'rect', 'x': 218, 'y': 242, 'width': 206, 'height': 57}
# {'name': 'rect', 'x': 7, 'y': 242, 'width': 206, 'height': 57}
# {'name': 'rect', 'x': 8, 'y': 302, 'width': 28, 'height': 30}
# {'name': 'rect', 'x': 37, 'y': 304, 'width': 282, 'height': 23}
# {'name': 'rect', 'x': 216, 'y': 335, 'width': 30, 'height': 37}
# {'name': 'rect', 'x': 243, 'y': 340, 'width': 179, 'height': 26}
# {'name': 'rect', 'x': 6, 'y': 333, 'width': 30, 'height': 37}
# {'name': 'rect', 'x': 33, 'y': 338, 'width': 179, 'height': 26}
# {'name': 'rect', 'x': 7, 'y': 373, 'width': 416, 'height': 53}
# {'name': 'rect', 'x': 9, 'y': 7, 'width': 120, 'height': 38}
# {'name': 'rect', 'x': 7, 'y': 45, 'width': 294, 'height': 31}
# {'name': 'rect', 'x': 3, 'y': 79, 'width': 340, 'height': 10}
# {'name': 'rect', 'x': 5, 'y': 281, 'width': 338, 'height': 55}
# {'name': 'rect', 'x': 6, 'y': 377, 'width': 165, 'height': 55}
# {'name': 'rect', 'x': 177, 'y': 97, 'width': 165, 'height': 55}
# {'name': 'rect', 'x': 5, 'y': 160, 'width': 338, 'height': 55}
# {'name': 'rect', 'x': 5, 'y': 222, 'width': 338, 'height': 55}
# {'name': 'rect', 'x': 5, 'y': 98, 'width': 165, 'height': 55}
# {'name': 'rect', 'x': 7, 'y': 347, 'width': 21, 'height': 21}
# {'name': 'rect', 'x': 29, 'y': 347, 'width': 275, 'height': 27}
# {'name': 'rect', 'x': 5, 'y': 198, 'width': 78, 'height': 28}
# {'name': 'rect', 'x': 86, 'y': 187, 'width': 225, 'height': 46}
# {'name': 'rect', 'x': 3, 'y': 12, 'width': 78, 'height': 28}
# {'name': 'rect', 'x': 84, 'y': 1, 'width': 225, 'height': 46}
# {'name': 'rect', 'x': 4, 'y': 68, 'width': 78, 'height': 28}
# {'name': 'rect', 'x': 85, 'y': 57, 'width': 225, 'height': 46}
# {'name': 'rect', 'x': 5, 'y': 139, 'width': 78, 'height': 28}
# {'name': 'rect', 'x': 86, 'y': 128, 'width': 225, 'height': 46}
# {'name': 'rect', 'x': 65, 'y': 260, 'width': 178, 'height': 46}
# {'name': 'rect', 'x': 87, 'y': 104, 'width': 213, 'height': 15}
# {'name': 'rect', 'x': 13, 'y': 15, 'width': 371, 'height': 78}
# {'name': 'rect', 'x': 17, 'y': 100, 'width': 383, 'height': 66}
# {'name': 'rect', 'x': 23, 'y': 168, 'width': 162, 'height': 20}
# {'name': 'rect', 'x': 20, 'y': 186, 'width': 383, 'height': 43}
# {'name': 'rect', 'x': 23, 'y': 236, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 22, 'y': 256, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 19, 'y': 592, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 18, 'y': 612, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 22, 'y': 306, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 21, 'y': 326, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 22, 'y': 381, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 21, 'y': 401, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 451, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 19, 'y': 471, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 17, 'y': 521, 'width': 118, 'height': 19}
# {'name': 'rect', 'x': 16, 'y': 541, 'width': 385, 'height': 46}
# {'name': 'rect', 'x': 20, 'y': 668, 'width': 371, 'height': 69}
# {'name': 'rect', 'x': 270, 'y': 777, 'width': 123, 'height': 52}
# {'name': 'rect', 'x': 42, 'y': 6, 'width': 126, 'height': 34}
# {'name': 'rect', 'x': 2, 'y': 234, 'width': 125, 'height': 15}
# {'name': 'rect', 'x': 2, 'y': 247, 'width': 209, 'height': 37}
# {'name': 'rect', 'x': 2, 'y': 86, 'width': 69, 'height': 15}
# {'name': 'rect', 'x': 2, 'y': 99, 'width': 209, 'height': 37}
# {'name': 'rect', 'x': 0, 'y': 137, 'width': 69, 'height': 15}
# {'name': 'rect', 'x': 0, 'y': 150, 'width': 209, 'height': 37}
# {'name': 'rect', 'x': 2, 'y': 186, 'width': 69, 'height': 15}
# {'name': 'rect', 'x': 2, 'y': 199, 'width': 209, 'height': 37}
# {'name': 'rect', 'x': 2, 'y': 323, 'width': 211, 'height': 38}
# {'name': 'rect', 'x': 100, 'y': 5, 'width': 70, 'height': 29}
# {'name': 'rect', 'x': 155, 'y': 49, 'width': 38, 'height': 25}
# {'name': 'rect', 'x': 70, 'y': 49, 'width': 38, 'height': 25}
# {'name': 'rect', 'x': 111, 'y': 49, 'width': 38, 'height': 25}
# {'name': 'rect', 'x': 89, 'y': 120, 'width': 92, 'height': 26}
# {'name': 'rect', 'x': 89, 'y': 348, 'width': 98, 'height': 24}
# {'name': 'rect', 'x': 34, 'y': 284, 'width': 224, 'height': 36}
# {'name': 'rect', 'x': 5, 'y': 278, 'width': 28, 'height': 44}
# {'name': 'rect', 'x': 34, 'y': 164, 'width': 224, 'height': 36}
# {'name': 'rect', 'x': 5, 'y': 158, 'width': 28, 'height': 44}
# {'name': 'rect', 'x': 34, 'y': 226, 'width': 224, 'height': 36}
# {'name': 'rect', 'x': 5, 'y': 220, 'width': 28, 'height': 44}
# {'name': 'rect', 'x': 5, 'y': 388, 'width': 127, 'height': 46}
# {'name': 'rect', 'x': 5, 'y': 214, 'width': 88, 'height': 18}
# {'name': 'rect', 'x': 3, 'y': 233, 'width': 570, 'height': 43}
# {'name': 'rect', 'x': 5, 'y': 2, 'width': 55, 'height': 18}
# {'name': 'rect', 'x': 7, 'y': 21, 'width': 570, 'height': 43}
# {'name': 'rect', 'x': 4, 'y': 74, 'width': 55, 'height': 18}
# {'name': 'rect', 'x': 6, 'y': 93, 'width': 570, 'height': 43}
# {'name': 'rect', 'x': 7, 'y': 146, 'width': 65, 'height': 18}
# {'name': 'rect', 'x': 5, 'y': 165, 'width': 570, 'height': 43}
# {'name': 'rect', 'x': 3, 'y': 290, 'width': 32, 'height': 37}
# {'name': 'rect', 'x': 35, 'y': 290, 'width': 546, 'height': 93}
# {'name': 'rect', 'x': 15, 'y': 208, 'width': 571, 'height': 82}
# {'name': 'rect', 'x': 13, 'y': 18, 'width': 571, 'height': 82}
# {'name': 'rect', 'x': 15, 'y': 112, 'width': 571, 'height': 82}
# {'name': 'rect', 'x': 14, 'y': 299, 'width': 39, 'height': 40}
# {'name': 'rect', 'x': 63, 'y': 300, 'width': 513, 'height': 38}
# {'name': 'rect', 'x': 16, 'y': 360, 'width': 143, 'height': 86}
# {'name': 'rect', 'x': 9, 'y': 281, 'width': 380, 'height': 51}
# {'name': 'rect', 'x': 93, 'y': 20, 'width': 101, 'height': 38}
# {'name': 'rect', 'x': 200, 'y': 20, 'width': 101, 'height': 38}
# {'name': 'rect', 'x': 11, 'y': 217, 'width': 378, 'height': 45}
# {'name': 'rect', 'x': 13, 'y': 64, 'width': 378, 'height': 40}
# {'name': 'rect', 'x': 11, 'y': 116, 'width': 378, 'height': 40}
# {'name': 'rect', 'x': 11, 'y': 168, 'width': 378, 'height': 40}
# {'name': 'rect', 'x': 90, 'y': 6, 'width': 60, 'height': 25}
# {'name': 'rect', 'x': 66, 'y': 142, 'width': 25, 'height': 30}
# {'name': 'rect', 'x': 92, 'y': 140, 'width': 96, 'height': 34}
# {'name': 'rect', 'x': 18, 'y': 94, 'width': 213, 'height': 42}
# {'name': 'rect', 'x': 15, 'y': 42, 'width': 213, 'height': 42}
# {'name': 'rect', 'x': 12, 'y': 193, 'width': 97, 'height': 27}
# {'name': 'rect', 'x': 147, 'y': 182, 'width': 82, 'height': 39}
# {'name': 'rect', 'x': 27, 'y': 1, 'width': 226, 'height': 34}
# {'name': 'rect', 'x': 34, 'y': 35, 'width': 210, 'height': 18}
# {'name': 'rect', 'x': 24, 'y': 100, 'width': 234, 'height': 35}
# {'name': 'rect', 'x': 2, 'y': 263, 'width': 270, 'height': 53}
# {'name': 'rect', 'x': 3, 'y': 154, 'width': 270, 'height': 53}
# {'name': 'rect', 'x': 3, 'y': 211, 'width': 270, 'height': 53}
# {'name': 'rect', 'x': 52, 'y': 324, 'width': 168, 'height': 43}
# Images: 38
# Classes: ['BG', 'input', 'button', 'text', 'select', 'checkbox', 'radiobutton', 'image']

# %% [markdown]
# ## Load Model

# %%
# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)
# Out:
# WARNING:tensorflow:From /home/user/Desktop/Programming/Keras/Mask_R_CNN/mask_rcnn_venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Set path to form_login weights file

# Download file from the Releases page and set its path
# https://github.com/matterport/Mask_RCNN/releases
# weights_path = "/path/to/mask_rcnn_form_login.h5"

# Or, load the last model you trained
#weights_path = model.find_last()
weights_path=BALLON_WEIGHTS_PATH

# Load weights
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True)
# Out:
# Loading weights  /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/mask_rcnn_form_login_0026.h5

# %% [markdown]
# ## Run Detection

# %%
image_id = random.choice(dataset.image_ids)
image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset, config, image_id, use_mini_mask=False)
info = dataset.image_info[image_id]
print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                       dataset.image_reference(image_id)))

# Run object detection
results = model.detect([image], verbose=1)

# Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            dataset.class_names, r['scores'], ax=ax,
                            title="Predictions")
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
# Out:
# image ID: form_login.sign-up-page-shopify.png (4) /home/user/Desktop/Programming/Keras/Mask_R_CNN/Mask_RCNN/datasets/form_login_ilya/train_filtered/val/sign-up-page-shopify.png
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 20)               min:    0.00000  max: 1024.00000  int64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# gt_class_id              shape: (5,)                  min:    1.00000  max:    3.00000  int32
# gt_bbox                  shape: (5, 4)                min:    4.00000  max: 1020.00000  int32
# gt_mask                  shape: (1024, 1024, 5)       min:    0.00000  max:    1.00000  bool

# %% [markdown]
# ## Color Splash
#
# This is for illustration. You can call `form_login.py` with the `splash` option to get better images without the black padding.

# %%
splash = form_login.color_splash(image, r['masks'])
display_images([splash], cols=1)

# %% [markdown]
# ## Step by Step Prediction

# %% [markdown]
# ## Stage 1: Region Proposal Network
#
# The Region Proposal Network (RPN) runs a lightweight binary classifier on a lot of boxes (anchors) over the image and returns object/no-object scores. Anchors with high *objectness* score (positive anchors) are passed to the stage two to be classified.
#
# Often, even positive anchors don't cover objects fully. So the RPN also regresses a refinement (a delta in location and size) to be applied to the anchors to shift it and resize it a bit to the correct boundaries of the object.

# %% [markdown]
# ### 1.a RPN Targets
#
# The RPN targets are the training values for the RPN. To generate the targets, we start with a grid of anchors that cover the full image at different scales, and then we compute the IoU of the anchors with ground truth object. Positive anchors are those that have an IoU >= 0.7 with any ground truth object, and negative anchors are those that don't cover any object by more than 0.3 IoU. Anchors in between (i.e. cover an object by IoU >= 0.3 but < 0.7) are considered neutral and excluded from training.
#
# To train the RPN regressor, we also compute the shift and resizing needed to make the anchor cover the ground truth object completely.

# %%
# Generate RPN trainig targets
# target_rpn_match is 1 for positive anchors, -1 for negative anchors
# and 0 for neutral anchors.
target_rpn_match, target_rpn_bbox = modellib.build_rpn_targets(
    image.shape, model.anchors, gt_class_id, gt_bbox, model.config)
log("target_rpn_match", target_rpn_match)
log("target_rpn_bbox", target_rpn_bbox)

positive_anchor_ix = np.where(target_rpn_match[:] == 1)[0]
negative_anchor_ix = np.where(target_rpn_match[:] == -1)[0]
neutral_anchor_ix = np.where(target_rpn_match[:] == 0)[0]
positive_anchors = model.anchors[positive_anchor_ix]
negative_anchors = model.anchors[negative_anchor_ix]
neutral_anchors = model.anchors[neutral_anchor_ix]
log("positive_anchors", positive_anchors)
log("negative_anchors", negative_anchors)
log("neutral anchors", neutral_anchors)

# Apply refinement deltas to positive anchors
refined_anchors = utils.apply_box_deltas(
    positive_anchors,
    target_rpn_bbox[:positive_anchors.shape[0]] * model.config.RPN_BBOX_STD_DEV)
log("refined_anchors", refined_anchors, )
# Out:
# target_rpn_match         shape: (261888,)             min:   -1.00000  max:    1.00000  int32
# target_rpn_bbox          shape: (256, 4)              min:   -6.42197  max:    5.95240  float64
# positive_anchors         shape: (103, 4)              min:   21.96133  max: 1013.01934  float64
# negative_anchors         shape: (153, 4)              min:  -22.62742  max: 1120.00000  float64
# neutral anchors          shape: (261632, 4)           min: -362.03867  max: 1322.03867  float64
# refined_anchors          shape: (103, 4)              min:    3.99997  max: 1020.00012  float32

# %%
# Display positive anchors before refinement (dotted) and
# after refinement (solid).
visualize.draw_boxes(image, boxes=positive_anchors, refined_boxes=refined_anchors, ax=get_ax())

# %% [markdown]
# ### 1.b RPN Predictions
#
# Here we run the RPN graph and display its predictions.

# %%
# Run RPN sub-graph
pillar = model.keras_model.get_layer("ROI").output  # node to start searching from

# TF 1.4 and 1.9 introduce new versions of NMS. Search for all names to support TF 1.3~1.10
nms_node = model.ancestor(pillar, "ROI/rpn_non_max_suppression:0")
if nms_node is None:
    nms_node = model.ancestor(pillar, "ROI/rpn_non_max_suppression/NonMaxSuppressionV2:0")
if nms_node is None: #TF 1.9-1.10
    nms_node = model.ancestor(pillar, "ROI/rpn_non_max_suppression/NonMaxSuppressionV3:0")

rpn = model.run_graph([image], [
    ("rpn_class", model.keras_model.get_layer("rpn_class").output),
    ("pre_nms_anchors", model.ancestor(pillar, "ROI/pre_nms_anchors:0")),
    ("refined_anchors", model.ancestor(pillar, "ROI/refined_anchors:0")),
    ("refined_anchors_clipped", model.ancestor(pillar, "ROI/refined_anchors_clipped:0")),
    ("post_nms_anchor_ix", nms_node),
    ("proposals", model.keras_model.get_layer("ROI").output),
])
# Out:
# rpn_class                shape: (1, 261888, 2)        min:    0.00000  max:    1.00000  float32
# pre_nms_anchors          shape: (1, 6000, 4)          min:   -0.35390  max:    1.29134  float32
# refined_anchors          shape: (1, 6000, 4)          min:   -1.31771  max:    2.28521  float32
# refined_anchors_clipped  shape: (1, 6000, 4)          min:    0.00000  max:    1.00000  float32
# post_nms_anchor_ix       shape: (1000,)               min:    0.00000  max: 5411.00000  int32
# proposals                shape: (1, 1000, 4)          min:    0.00000  max:    1.00000  float32

# %%
# Show top anchors by score (before refinement)
limit = 100
sorted_anchor_ids = np.argsort(rpn['rpn_class'][:,:,1].flatten())[::-1]
visualize.draw_boxes(image, boxes=model.anchors[sorted_anchor_ids[:limit]], ax=get_ax())

# %%
# Show top anchors with refinement. Then with clipping to image boundaries
limit = 50
ax = get_ax(1, 2)
pre_nms_anchors = utils.denorm_boxes(rpn["pre_nms_anchors"][0], image.shape[:2])
refined_anchors = utils.denorm_boxes(rpn["refined_anchors"][0], image.shape[:2])
refined_anchors_clipped = utils.denorm_boxes(rpn["refined_anchors_clipped"][0], image.shape[:2])
visualize.draw_boxes(image, boxes=pre_nms_anchors[:limit],
                     refined_boxes=refined_anchors[:limit], ax=ax[0])
visualize.draw_boxes(image, refined_boxes=refined_anchors_clipped[:limit], ax=ax[1])

# %%
# Show refined anchors after non-max suppression
limit = 50
ixs = rpn["post_nms_anchor_ix"][:limit]
visualize.draw_boxes(image, refined_boxes=refined_anchors_clipped[ixs], ax=get_ax())

# %%
# Show final proposals
# These are the same as the previous step (refined anchors 
# after NMS) but with coordinates normalized to [0, 1] range.
limit = 50
# Convert back to image coordinates for display
h, w = config.IMAGE_SHAPE[:2]
proposals = rpn['proposals'][0, :limit] * np.array([h, w, h, w])
visualize.draw_boxes(image, refined_boxes=proposals, ax=get_ax())

# %% [markdown]
# ## Stage 2: Proposal Classification
#
# This stage takes the region proposals from the RPN and classifies them.

# %% [markdown]
# ### 2.a Proposal Classification
#
# Run the classifier heads on proposals to generate class propbabilities and bounding box regressions.

# %%
# Get input and output to classifier and mask heads.
mrcnn = model.run_graph([image], [
    ("proposals", model.keras_model.get_layer("ROI").output),
    ("probs", model.keras_model.get_layer("mrcnn_class").output),
    ("deltas", model.keras_model.get_layer("mrcnn_bbox").output),
    ("masks", model.keras_model.get_layer("mrcnn_mask").output),
    ("detections", model.keras_model.get_layer("mrcnn_detection").output),
])
# Out:
# proposals                shape: (1, 1000, 4)          min:    0.00000  max:    1.00000  float32
# probs                    shape: (1, 1000, 8)          min:    0.00000  max:    0.99999  float32
# deltas                   shape: (1, 1000, 8, 4)       min:   -4.45078  max:    4.48398  float32
# masks                    shape: (1, 100, 28, 28, 8)   min:    0.00028  max:    0.99999  float32
# detections               shape: (1, 100, 6)           min:    0.00000  max:    2.00000  float32

# %%
# Get detection class IDs. Trim zero padding.
det_class_ids = mrcnn['detections'][0, :, 4].astype(np.int32)
det_count = np.where(det_class_ids == 0)[0][0]
det_class_ids = det_class_ids[:det_count]
detections = mrcnn['detections'][0, :det_count]

print("{} detections: {}".format(
    det_count, np.array(dataset.class_names)[det_class_ids]))

captions = ["{} {:.3f}".format(dataset.class_names[int(c)], s) if c > 0 else ""
            for c, s in zip(detections[:, 4], detections[:, 5])]
visualize.draw_boxes(
    image, 
    refined_boxes=utils.denorm_boxes(detections[:, :4], image.shape[:2]),
    visibilities=[2] * len(detections),
    captions=captions, title="Detections",
    ax=get_ax())
# Out:
# 3 detections: ['button' 'input' 'input']

# %% [markdown]
# ### 2.c Step by Step Detection
#
# Here we dive deeper into the process of processing the detections.

# %%
# Proposals are in normalized coordinates. Scale them
# to image coordinates.
h, w = config.IMAGE_SHAPE[:2]
proposals = np.around(mrcnn["proposals"][0] * np.array([h, w, h, w])).astype(np.int32)

# Class ID, score, and mask per proposal
roi_class_ids = np.argmax(mrcnn["probs"][0], axis=1)
roi_scores = mrcnn["probs"][0, np.arange(roi_class_ids.shape[0]), roi_class_ids]
roi_class_names = np.array(dataset.class_names)[roi_class_ids]
roi_positive_ixs = np.where(roi_class_ids > 0)[0]

# How many ROIs vs empty rows?
print("{} Valid proposals out of {}".format(np.sum(np.any(proposals, axis=1)), proposals.shape[0]))
print("{} Positive ROIs".format(len(roi_positive_ixs)))

# Class counts
print(list(zip(*np.unique(roi_class_names, return_counts=True))))
# Out:
# 1000 Valid proposals out of 1000
# 87 Positive ROIs
# [('BG', 913), ('button', 20), ('input', 44), ('text', 23)]

# %%
# Display a random sample of proposals.
# Proposals classified as background are dotted, and
# the rest show their class and confidence score.
limit = 200
ixs = np.random.randint(0, proposals.shape[0], limit)
captions = ["{} {:.3f}".format(dataset.class_names[c], s) if c > 0 else ""
            for c, s in zip(roi_class_ids[ixs], roi_scores[ixs])]
visualize.draw_boxes(image, boxes=proposals[ixs],
                     visibilities=np.where(roi_class_ids[ixs] > 0, 2, 1),
                     captions=captions, title="ROIs Before Refinement",
                     ax=get_ax())

# %% [markdown]
# #### Apply Bounding Box Refinement

# %%
# Class-specific bounding box shifts.
roi_bbox_specific = mrcnn["deltas"][0, np.arange(proposals.shape[0]), roi_class_ids]
log("roi_bbox_specific", roi_bbox_specific)

# Apply bounding box transformations
# Shape: [N, (y1, x1, y2, x2)]
refined_proposals = utils.apply_box_deltas(
    proposals, roi_bbox_specific * config.BBOX_STD_DEV).astype(np.int32)
log("refined_proposals", refined_proposals)

# Show positive proposals
# ids = np.arange(roi_boxes.shape[0])  # Display all
limit = 5
ids = np.random.randint(0, len(roi_positive_ixs), limit)  # Display random sample
captions = ["{} {:.3f}".format(dataset.class_names[c], s) if c > 0 else ""
            for c, s in zip(roi_class_ids[roi_positive_ixs][ids], roi_scores[roi_positive_ixs][ids])]
visualize.draw_boxes(image, boxes=proposals[roi_positive_ixs][ids],
                     refined_boxes=refined_proposals[roi_positive_ixs][ids],
                     visibilities=np.where(roi_class_ids[roi_positive_ixs][ids] > 0, 1, 0),
                     captions=captions, title="ROIs After Refinement",
                     ax=get_ax())
# Out:
# roi_bbox_specific        shape: (1000, 4)             min:   -4.02080  max:    3.02369  float32
# refined_proposals        shape: (1000, 4)             min: -122.00000  max: 1217.00000  int32

# %% [markdown]
# #### Filter Low Confidence Detections

# %%
# Remove boxes classified as background
keep = np.where(roi_class_ids > 0)[0]
print("Keep {} detections:\n{}".format(keep.shape[0], keep))
# Out:
# Keep 87 detections:
# [  1   4   5   7  10  15  17  18  20  21  22  25  28  41  44  45  52  53
#   58  60  61  66  67  69  73  75  76  79  86  98  99 102 120 137 141 145
#  152 165 166 167 170 175 178 182 191 192 207 217 234 250 254 255 262 271
#  286 295 333 338 362 363 400 448 453 461 483 491 506 557 569 596 606 622
#  627 632 644 664 698 705 731 742 806 822 872 918 922 926 949]

# %%
# Remove low confidence detections
keep = np.intersect1d(keep, np.where(roi_scores >= config.DETECTION_MIN_CONFIDENCE)[0])
print("Remove boxes below {} confidence. Keep {}:\n{}".format(
    config.DETECTION_MIN_CONFIDENCE, keep.shape[0], keep))
# Out:
# Remove boxes below 0.9 confidence. Keep 14:
# [  7  10  28  45  61 152 170 182 191 234 362 606 698 806]

# %% [markdown]
# #### Per-Class Non-Max Suppression

# %%
# Apply per-class non-max suppression
pre_nms_boxes = refined_proposals[keep]
pre_nms_scores = roi_scores[keep]
pre_nms_class_ids = roi_class_ids[keep]

nms_keep = []
for class_id in np.unique(pre_nms_class_ids):
    # Pick detections of this class
    ixs = np.where(pre_nms_class_ids == class_id)[0]
    # Apply NMS
    class_keep = utils.non_max_suppression(pre_nms_boxes[ixs], 
                                            pre_nms_scores[ixs],
                                            config.DETECTION_NMS_THRESHOLD)
    # Map indicies
    class_keep = keep[ixs[class_keep]]
    nms_keep = np.union1d(nms_keep, class_keep)
    print("{:22}: {} -> {}".format(dataset.class_names[class_id][:20], 
                                   keep[ixs], class_keep))

keep = np.intersect1d(keep, nms_keep).astype(np.int32)
print("\nKept after per-class NMS: {}\n{}".format(keep.shape[0], keep))
# Out:
# input                 : [ 28  45 170 182 234 362 698] -> [28 45]
# button                : [  7  10  61 152 191 606 806] -> [7]
#
# Kept after per-class NMS: 3
# [ 7 28 45]

# %%
# Show final detections
ixs = np.arange(len(keep))  # Display all
# ixs = np.random.randint(0, len(keep), 10)  # Display random sample
captions = ["{} {:.3f}".format(dataset.class_names[c], s) if c > 0 else ""
            for c, s in zip(roi_class_ids[keep][ixs], roi_scores[keep][ixs])]
visualize.draw_boxes(
    image, boxes=proposals[keep][ixs],
    refined_boxes=refined_proposals[keep][ixs],
    visibilities=np.where(roi_class_ids[keep][ixs] > 0, 1, 0),
    captions=captions, title="Detections after NMS",
    ax=get_ax())

# %% [markdown]
# ## Stage 3: Generating Masks
#
# This stage takes the detections (refined bounding boxes and class IDs) from the previous layer and runs the mask head to generate segmentation masks for every instance.

# %% [markdown]
# ### 3.a Mask Targets
#
# These are the training targets for the mask branch

# %%
display_images(np.transpose(gt_mask, [2, 0, 1]), cmap="Blues")

# %% [markdown]
# ### 3.b Predicted Masks

# %%
# Get predictions of mask head
mrcnn = model.run_graph([image], [
    ("detections", model.keras_model.get_layer("mrcnn_detection").output),
    ("masks", model.keras_model.get_layer("mrcnn_mask").output),
])

# Get detection class IDs. Trim zero padding.
det_class_ids = mrcnn['detections'][0, :, 4].astype(np.int32)
det_count = np.where(det_class_ids == 0)[0][0]
det_class_ids = det_class_ids[:det_count]

print("{} detections: {}".format(
    det_count, np.array(dataset.class_names)[det_class_ids]))
# Out:
# detections               shape: (1, 100, 6)           min:    0.00000  max:    2.00000  float32
# masks                    shape: (1, 100, 28, 28, 8)   min:    0.00028  max:    0.99999  float32
# 3 detections: ['button' 'input' 'input']

# %%
# Masks
det_boxes = utils.denorm_boxes(mrcnn["detections"][0, :, :4], image.shape[:2])
det_mask_specific = np.array([mrcnn["masks"][0, i, :, :, c] 
                              for i, c in enumerate(det_class_ids)])
det_masks = np.array([utils.unmold_mask(m, det_boxes[i], image.shape)
                      for i, m in enumerate(det_mask_specific)])
log("det_mask_specific", det_mask_specific)
log("det_masks", det_masks)
# Out:
# det_mask_specific        shape: (3, 28, 28)           min:    0.00083  max:    0.99999  float32
# det_masks                shape: (3, 1024, 1024)       min:    0.00000  max:    1.00000  bool

# %%
display_images(det_mask_specific[:4] * 255, cmap="Blues", interpolation="none")

# %%
display_images(det_masks[:4] * 255, cmap="Blues", interpolation="none")

# %% [markdown]
# ## Visualize Activations
#
# In some cases it helps to look at the output from different layers and visualize them to catch issues and odd patterns.

# %%
# Get activations of a few sample layers
activations = model.run_graph([image], [
    ("input_image",        tf.identity(model.keras_model.get_layer("input_image").output)),
    ("res2c_out",          model.keras_model.get_layer("res2c_out").output),
    ("res3c_out",          model.keras_model.get_layer("res3c_out").output),
    # ("res4w_out",          model.keras_model.get_layer("res4w_out").output),  # for resnet100
    ("rpn_bbox",           model.keras_model.get_layer("rpn_bbox").output),
    ("roi",                model.keras_model.get_layer("ROI").output),
])
# Out:
# input_image              shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10001  float32
# res2c_out                shape: (1, 256, 256, 256)    min:    0.00000  max:   25.22287  float32
# res3c_out                shape: (1, 128, 128, 512)    min:    0.00000  max:   30.38463  float32
# rpn_bbox                 shape: (1, 261888, 4)        min:  -16.06090  max:   27.03650  float32
# roi                      shape: (1, 1000, 4)          min:    0.00000  max:    1.00000  float32

# %%
# Input image (normalized)
_ = plt.imshow(modellib.unmold_image(activations["input_image"][0],config))

# %%
# Backbone feature map
display_images(np.transpose(activations["res2c_out"][0,:,:,:4], [2, 0, 1]), cols=4)
